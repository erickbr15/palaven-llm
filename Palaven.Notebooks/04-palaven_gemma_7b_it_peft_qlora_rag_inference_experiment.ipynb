# %% [markdown]
# # Inference with `google/gemma-7b-it`. Fine-tuned using PEFT QLoRA + RAG
#
# ## Purpose
# This notebook performs inference using the `google/gemma-7b-it` language model from Hugging Face's `transformers` library, fine-tuned using **PEFT (Parameter-Efficient Fine-Tuning)** with **QLoRA** (Quantized Low Rank Adaptation) and enhanced by **Retrieval-Augmented Generation (RAG)**. The test dataset consists of 1363 records, fetched via an HTTP call to the **Palaven API**—a custom API developed exclusively for this thesis. The generated responses, along with evaluation metrics, are saved back to the Palaven API for future analysis.
#
# ## Overview
#
# 1. **Declaration of Global Variables**:
#     - The notebook initializes all necessary global variables, including paths, API credentials, batch sizes, and any configuration settings required for inference and evaluation.
#
# 2. **Loading the Fine-tuned Model and Tokenizer**:
#     - The `google/gemma-7b-it` model and its corresponding tokenizer are loaded from the Hugging Face library (`transformers`).
#     - The model has been fine-tuned using **PEFT** with **QLoRA**, allowing for efficient adaptation to the specific task with reduced memory and computational costs.
#     - The **RAG** component is integrated to retrieve relevant external knowledge during inference, enhancing the model's ability to generate more contextually informed responses.
#
# 3. **Inference Execution**:
#     - **Dataset fetching**: The test dataset, consisting of 1363 records, is retrieved from the cloud via the **Palaven API** using an HTTP request.
#     - **Batch processing**: The dataset is processed in batches, with each batch containing 50 instructions. This approach optimizes memory usage and processing time, especially when using a fine-tuned model with retrieval capabilities.
#     - **Model Inference**: For each instruction in the dataset, the fine-tuned `google/gemma-7b-it` model, enhanced by the **RAG** component, generates responses by leveraging retrieved external information.
#     - **Saving responses**: All generated responses are persisted back to the Palaven API for future evaluation and analysis.
#
# 4. **Evaluation Metrics**:
#     - **BERTScore**: Precision, Recall, and F1 scores are calculated for each batch to measure the semantic similarity between the generated responses and the ground truth.
#     - **ROUGE**: ROUGE 1, ROUGE 2, and ROUGE L scores are computed to evaluate n-gram overlap, with Precision, Recall, and F1 calculated for each metric.
#     - **BLEU**: The BLEU score is calculated for each batch, assessing the fluency and correctness of the generated text based on n-gram precision.
#     - **Persisting metrics**: All computed metrics are persisted to the cloud via the Palaven API, allowing for further analysis and comparison between experiments (e.g., out-of-the-box vs. fine-tuned models, with and without RAG).

# %% [markdown]
# ## Key Sections
# ### 1. Declaration of global variables
#
# | **Variable**             | **Description**                                                                                   | **Value**                                                   |
# |--------------------------|---------------------------------------------------------------------------------------------------|-------------------------------------------------------------|
# | `hface_read_token`        | Access token for reading from Hugging Face, retrieved from user data.                             | `userdata.get('hface-read-token')`                          |
# | `palaven_base_url`        | Base URL for the Palaven API, retrieved from user data.                                           | `userdata.get('palaven-base-url')`                          |
# | `batch_size`              | Batch size for inference and evaluation execution.                                                | `50`                                                        |
# | `dataset_id`              | Unique identifier for the dataset used in evaluation.                                             | `'F0444B12-5485-4299-B03B-3BDB6D4A2578'`                    |
# | `evaluation_session_id`   | Unique identifier for the current evaluation session.                                             | `'EB9C5839-7B20-4D7D-B3F7-17528180676D'`                    |
# | `llm_palaven_name`        | Name of the model used in Palaven.                                                 | `'google-gemma'`                                            |
# | `llm_model_name`          | Full name of the model used from Hugging Face.                                                    | `'google/gemma-7b-it'`                                      |
# | `device_info`             | Information about the device where the inferences and evaluations are executed.                   | `'GPU A100'`                                                |

# %%
from google.colab import userdata
from palaven_api_v2 import PalavenApi

hface_read_token = userdata.get('hface-read-token')
palaven_base_url = userdata.get('palaven-base-url')

batch_size = 50
dataset_id = 'F0444B12-5485-4299-B03B-3BDB6D4A2578'
evaluation_session_id = 'EB9C5839-7B20-4D7D-B3F7-17528180676D'
llm_palaven_name = 'google-gemma'
llm_model_name = 'google/gemma-7b-it'
llm_palaven_peft = '/content/drive/MyDrive/Colab Notebooks/palaven/gemma-7b-it-palaven'
device_info = 'GPU A100'

palaven_api = PalavenApi(palaven_base_url)

# %% [markdown]
# ### 2. Load the base model and the tokenizer

# %%
# !pip install -U transformers
# !pip install accelerate
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Collecting transformers
#   Downloading transformers-4.44.2-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)
# Downloading transformers-4.44.2-py3-none-any.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 124.3 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.42.4
#     Uninstalling transformers-4.42.4:
#       Successfully uninstalled transformers-4.42.4
# Successfully installed transformers-4.44.2
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.32.1)
# Requirement already satisfied: numpy<2.0.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.4.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.23.5)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2024.6.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained(llm_model_name, token=hface_read_token)
base_model = AutoModelForCausalLM.from_pretrained(llm_model_name, device_map="auto", token=hface_read_token)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/34.2k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/694 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/2.11G [00:00<?, ?B/s]
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %% [markdown]
# ### 2.1. Load the PEFT QLoRA finetuned adapters and merge them with the base model google/gemma-7b-it

# %%
# !pip install peft
# Out:
# Collecting peft
#   Downloading peft-0.12.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from peft) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from peft) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from peft) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from peft) (2.4.0+cu121)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from peft) (4.44.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from peft) (4.66.5)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from peft) (0.32.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from peft) (0.4.4)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from peft) (0.23.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (2024.6.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->peft) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers->peft) (0.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->peft) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->peft) (1.3.0)
# Downloading peft-0.12.0-py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.4/296.4 kB 22.4 MB/s eta 0:00:00
# Installing collected packages: peft
# Successfully installed peft-0.12.0

# %%
from peft import PeftModel

peft_model = PeftModel.from_pretrained(base_model, llm_palaven_peft, token=hface_read_token)
model = peft_model.merge_and_unload()
model.to("cuda")
# Out:
# GemmaForCausalLM(
#   (model): GemmaModel(
#     (embed_tokens): Embedding(256000, 3072, padding_idx=0)
#     (layers): ModuleList(
#       (0-27): 28 x GemmaDecoderLayer(
#         (self_attn): GemmaSdpaAttention(
#           (q_proj): Linear(in_features=3072, out_features=4096, bias=False)
#           (k_proj): Linear(in_features=3072, out_features=4096, bias=False)
#           (v_proj): Linear(in_features=3072, out_features=4096, bias=False)
#           (o_proj): Linear(in_features=4096, out_features=3072, bias=False)
#           (rotary_emb): GemmaRotaryEmbedding()
#         )
#         (mlp): GemmaMLP(
#           (gate_proj): Linear(in_features=3072, out_features=24576, bias=False)
#           (up_proj): Linear(in_features=3072, out_features=24576, bias=False)
#           (down_proj): Linear(in_features=24576, out_features=3072, bias=False)
#           (act_fn): PytorchGELUTanh()
#         )
#         (input_layernorm): GemmaRMSNorm((3072,), eps=1e-06)
#         (post_attention_layernorm): GemmaRMSNorm((3072,), eps=1e-06)
#       )
#     )
#     (norm): GemmaRMSNorm((3072,), eps=1e-06)
#   )
#   (lm_head): Linear(in_features=3072, out_features=256000, bias=False)
# )

# %% [markdown]
# ### 3. Inference Execution

# %%
import time
import torch

def get_chat_completion(instruction_prompt, instruction_id, instruction_count):

  start_time = time.time()

  tokenized_instruction = tokenizer(instruction_prompt, return_tensors="pt").to("cuda")

  with torch.no_grad():
    chat_completion_result = model.generate(**tokenized_instruction, max_new_tokens=1000)

  chat_completion = tokenizer.decode(chat_completion_result[0])

  end_time = time.time()
  elapsed_time = end_time - start_time

  print(f'{instruction_count} - LLM-ChatCompletion. InstructionId: {instruction_id},  Elapsed-Time: {elapsed_time:.2f} seconds')

  return chat_completion, elapsed_time

# %%
def add_instruction_to_df(df, instruction_id, instruction):
    df.loc[instruction_id, 'instruction'] = instruction
    df.loc[instruction_id, 'chat_completion'] = None
    df.loc[instruction_id, 'elapsed_time'] = None

# %%
import pandas as pd
import numpy as np
import json

data_shape = {
    'instruction_id': [],
    'instruction': [],
    'chat_completion': [],
    'elapsed_time': []
}

for batch_number in range(1, 29):

  print(f'Start fetching batch {batch_number}')

  instructions = palaven_api.fetch_instruction_test_dataset(evaluation_session_id, batch_number=batch_number, evaluation_exercise='llmfinetunedrag')

  print(f'Start fetching batch done...')

  llm_responses_df = pd.DataFrame(data_shape)
  llm_responses_df.set_index('instruction_id', inplace=True)

  for item in instructions:
    add_instruction_to_df(llm_responses_df, item['instructionId'], item['instruction'])

  instruction_count = 1

  for index, row in llm_responses_df.iterrows():
    instruction = llm_responses_df.loc[index, 'instruction']

    query_augmentation_response = palaven_api.generate_augmented_prompt(llm_palaven_name, instruction)
    instruction_prompt = query_augmentation_response['prompt']

    instruction_id = int(index)

    chat_completion, elapsed_time = get_chat_completion(instruction_prompt, instruction_id, instruction_count)
    palaven_api.save_model_response(evaluation_session_id, 'llmfinetunedrag', batch_number, instruction_id, chat_completion, elapsed_time)

    torch.cuda.empty_cache()

    instruction_count += 1
# Out:
# Start fetching batch 1
# Start fetching batch done...
# <ipython-input-8-9ad68d3380dc>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '¿Bajo qué circunstancias los residentes en el extranjero deben pagar impuesto sobre la renta en México según el Artículo 1 de la Ley del Impuesto Sobre la Renta del 2024?' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[instruction_id, 'instruction'] = instruction
# 1 - LLM-ChatCompletion. InstructionId: 3878,  Elapsed-Time: 6.49 seconds
# Palaven.SaveResponse. InstructionId: 3878,  Elapsed-Time: 1.13 seconds
# 2 - LLM-ChatCompletion. InstructionId: 3880,  Elapsed-Time: 2.25 seconds
# Palaven.SaveResponse. InstructionId: 3880,  Elapsed-Time: 0.87 seconds
# 3 - LLM-ChatCompletion. InstructionId: 3882,  Elapsed-Time: 2.36 seconds
# Palaven.SaveResponse. InstructionId: 3882,  Elapsed-Time: 0.83 seconds
# 4 - LLM-ChatCompletion. InstructionId: 3884,  Elapsed-Time: 3.82 seconds
# Palaven.SaveResponse. InstructionId: 3884,  Elapsed-Time: 0.86 seconds
# 5 - LLM-ChatCompletion. InstructionId: 3886,  Elapsed-Time: 2.92 seconds
# Palaven.SaveResponse. InstructionId: 3886,  Elapsed-Time: 0.83 seconds
# 6 - LLM-ChatCompletion. InstructionId: 3888,  Elapsed-Time: 1.30 seconds
# Palaven.SaveResponse. InstructionId: 3888,  Elapsed-Time: 0.85 seconds
# 7 - LLM-ChatCompletion. InstructionId: 3894,  Elapsed-Time: 3.61 seconds
# Palaven.SaveResponse. InstructionId: 3894,  Elapsed-Time: 0.83 seconds
# 8 - LLM-ChatCompletion. InstructionId: 3896,  Elapsed-Time: 3.72 seconds
# Palaven.SaveResponse. InstructionId: 3896,  Elapsed-Time: 0.86 seconds
# 9 - LLM-ChatCompletion. InstructionId: 3898,  Elapsed-Time: 3.68 seconds
# Palaven.SaveResponse. InstructionId: 3898,  Elapsed-Time: 0.84 seconds
# 10 - LLM-ChatCompletion. InstructionId: 3900,  Elapsed-Time: 2.73 seconds
# Palaven.SaveResponse. InstructionId: 3900,  Elapsed-Time: 0.85 seconds
# 11 - LLM-ChatCompletion. InstructionId: 3902,  Elapsed-Time: 4.85 seconds
# Palaven.SaveResponse. InstructionId: 3902,  Elapsed-Time: 0.83 seconds
# 12 - LLM-ChatCompletion. InstructionId: 3904,  Elapsed-Time: 4.83 seconds
# Palaven.SaveResponse. InstructionId: 3904,  Elapsed-Time: 0.82 seconds
# 13 - LLM-ChatCompletion. InstructionId: 3906,  Elapsed-Time: 3.13 seconds
# Palaven.SaveResponse. InstructionId: 3906,  Elapsed-Time: 0.85 seconds
# 14 - LLM-ChatCompletion. InstructionId: 3908,  Elapsed-Time: 4.53 seconds
# Palaven.SaveResponse. InstructionId: 3908,  Elapsed-Time: 0.82 seconds
# 15 - LLM-ChatCompletion. InstructionId: 3918,  Elapsed-Time: 7.61 seconds
# Palaven.SaveResponse. InstructionId: 3918,  Elapsed-Time: 0.86 seconds
# 16 - LLM-ChatCompletion. InstructionId: 3920,  Elapsed-Time: 3.66 seconds
# Palaven.SaveResponse. InstructionId: 3920,  Elapsed-Time: 0.84 seconds
# 17 - LLM-ChatCompletion. InstructionId: 3922,  Elapsed-Time: 2.77 seconds
# Palaven.SaveResponse. InstructionId: 3922,  Elapsed-Time: 0.85 seconds
# 18 - LLM-ChatCompletion. InstructionId: 3924,  Elapsed-Time: 5.28 seconds
# Palaven.SaveResponse. InstructionId: 3924,  Elapsed-Time: 0.84 seconds
# 19 - LLM-ChatCompletion. InstructionId: 3926,  Elapsed-Time: 2.82 seconds
# Palaven.SaveResponse. InstructionId: 3926,  Elapsed-Time: 0.84 seconds
# 20 - LLM-ChatCompletion. InstructionId: 3928,  Elapsed-Time: 3.89 seconds
# Palaven.SaveResponse. InstructionId: 3928,  Elapsed-Time: 0.85 seconds
# 21 - LLM-ChatCompletion. InstructionId: 3930,  Elapsed-Time: 3.90 seconds
# Palaven.SaveResponse. InstructionId: 3930,  Elapsed-Time: 0.86 seconds
# 22 - LLM-ChatCompletion. InstructionId: 3938,  Elapsed-Time: 2.49 seconds
# Palaven.SaveResponse. InstructionId: 3938,  Elapsed-Time: 0.84 seconds
# 23 - LLM-ChatCompletion. InstructionId: 3940,  Elapsed-Time: 2.27 seconds
# Palaven.SaveResponse. InstructionId: 3940,  Elapsed-Time: 0.83 seconds
# 24 - LLM-ChatCompletion. InstructionId: 3942,  Elapsed-Time: 2.43 seconds
# Palaven.SaveResponse. InstructionId: 3942,  Elapsed-Time: 0.85 seconds
# 25 - LLM-ChatCompletion. InstructionId: 3944,  Elapsed-Time: 2.95 seconds
# Palaven.SaveResponse. InstructionId: 3944,  Elapsed-Time: 0.85 seconds
# 26 - LLM-ChatCompletion. InstructionId: 3946,  Elapsed-Time: 3.09 seconds
# Palaven.SaveResponse. InstructionId: 3946,  Elapsed-Time: 0.85 seconds
# 27 - LLM-ChatCompletion. InstructionId: 3948,  Elapsed-Time: 2.60 seconds
# Palaven.SaveResponse. InstructionId: 3948,  Elapsed-Time: 0.83 seconds
# 28 - LLM-ChatCompletion. InstructionId: 3950,  Elapsed-Time: 3.08 seconds
# Palaven.SaveResponse. InstructionId: 3950,  Elapsed-Time: 0.85 seconds
# 29 - LLM-ChatCompletion. InstructionId: 3952,  Elapsed-Time: 2.22 seconds
# Palaven.SaveResponse. InstructionId: 3952,  Elapsed-Time: 0.85 seconds
# 30 - LLM-ChatCompletion. InstructionId: 3962,  Elapsed-Time: 3.03 seconds
# Palaven.SaveResponse. InstructionId: 3962,  Elapsed-Time: 0.83 seconds
# 31 - LLM-ChatCompletion. InstructionId: 3964,  Elapsed-Time: 3.73 seconds
# Palaven.SaveResponse. InstructionId: 3964,  Elapsed-Time: 0.86 seconds
# 32 - LLM-ChatCompletion. InstructionId: 3966,  Elapsed-Time: 1.46 seconds
# Palaven.SaveResponse. InstructionId: 3966,  Elapsed-Time: 0.85 seconds
# 33 - LLM-ChatCompletion. InstructionId: 3968,  Elapsed-Time: 2.81 seconds
# Palaven.SaveResponse. InstructionId: 3968,  Elapsed-Time: 0.82 seconds
# 34 - LLM-ChatCompletion. InstructionId: 3970,  Elapsed-Time: 1.91 seconds
# Palaven.SaveResponse. InstructionId: 3970,  Elapsed-Time: 0.82 seconds
# 35 - LLM-ChatCompletion. InstructionId: 3972,  Elapsed-Time: 1.42 seconds
# Palaven.SaveResponse. InstructionId: 3972,  Elapsed-Time: 0.83 seconds
# 36 - LLM-ChatCompletion. InstructionId: 3974,  Elapsed-Time: 1.86 seconds
# Palaven.SaveResponse. InstructionId: 3974,  Elapsed-Time: 0.85 seconds
# 37 - LLM-ChatCompletion. InstructionId: 3981,  Elapsed-Time: 6.80 seconds
# Palaven.SaveResponse. InstructionId: 3981,  Elapsed-Time: 0.85 seconds
# 38 - LLM-ChatCompletion. InstructionId: 3983,  Elapsed-Time: 3.56 seconds
# Palaven.SaveResponse. InstructionId: 3983,  Elapsed-Time: 0.82 seconds
# 39 - LLM-ChatCompletion. InstructionId: 3985,  Elapsed-Time: 2.28 seconds
# Palaven.SaveResponse. InstructionId: 3985,  Elapsed-Time: 0.85 seconds
# 40 - LLM-ChatCompletion. InstructionId: 3987,  Elapsed-Time: 3.20 seconds
# Palaven.SaveResponse. InstructionId: 3987,  Elapsed-Time: 0.82 seconds
# 41 - LLM-ChatCompletion. InstructionId: 3989,  Elapsed-Time: 3.00 seconds
# Palaven.SaveResponse. InstructionId: 3989,  Elapsed-Time: 0.84 seconds
# 42 - LLM-ChatCompletion. InstructionId: 3991,  Elapsed-Time: 5.83 seconds
# Palaven.SaveResponse. InstructionId: 3991,  Elapsed-Time: 0.86 seconds
# 43 - LLM-ChatCompletion. InstructionId: 3993,  Elapsed-Time: 3.23 seconds
# Palaven.SaveResponse. InstructionId: 3993,  Elapsed-Time: 0.83 seconds
# 44 - LLM-ChatCompletion. InstructionId: 3995,  Elapsed-Time: 4.32 seconds
# Palaven.SaveResponse. InstructionId: 3995,  Elapsed-Time: 0.85 seconds
# 45 - LLM-ChatCompletion. InstructionId: 4005,  Elapsed-Time: 7.30 seconds
# Palaven.SaveResponse. InstructionId: 4005,  Elapsed-Time: 0.84 seconds
# 46 - LLM-ChatCompletion. InstructionId: 4007,  Elapsed-Time: 2.80 seconds
# Palaven.SaveResponse. InstructionId: 4007,  Elapsed-Time: 0.83 seconds
# 47 - LLM-ChatCompletion. InstructionId: 4009,  Elapsed-Time: 3.69 seconds
# Palaven.SaveResponse. InstructionId: 4009,  Elapsed-Time: 0.86 seconds
# 48 - LLM-ChatCompletion. InstructionId: 4011,  Elapsed-Time: 3.36 seconds
# Palaven.SaveResponse. InstructionId: 4011,  Elapsed-Time: 0.82 seconds
# 49 - LLM-ChatCompletion. InstructionId: 4013,  Elapsed-Time: 2.74 seconds
# Palaven.SaveResponse. InstructionId: 4013,  Elapsed-Time: 0.87 seconds
# 50 - LLM-ChatCompletion. InstructionId: 4015,  Elapsed-Time: 4.27 seconds
# Palaven.SaveResponse. InstructionId: 4015,  Elapsed-Time: 0.84 seconds
# Start fetching batch 2
# Start fetching batch done...
# <ipython-input-8-9ad68d3380dc>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '¿Para calcular la modificación en el valor de bienes o operaciones en un periodo de un mes, qué factor de ajuste se utiliza de acuerdo al Artículo 6 de la Ley del Impuesto Sobre la Renta del 2024?' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[instruction_id, 'instruction'] = instruction
# 1 - LLM-ChatCompletion. InstructionId: 4017,  Elapsed-Time: 3.61 seconds
# Palaven.SaveResponse. InstructionId: 4017,  Elapsed-Time: 0.86 seconds
# 2 - LLM-ChatCompletion. InstructionId: 4025,  Elapsed-Time: 4.15 seconds
# Palaven.SaveResponse. InstructionId: 4025,  Elapsed-Time: 0.83 seconds
# 3 - LLM-ChatCompletion. InstructionId: 4027,  Elapsed-Time: 3.32 seconds
# Palaven.SaveResponse. InstructionId: 4027,  Elapsed-Time: 0.83 seconds
# 4 - LLM-ChatCompletion. InstructionId: 4029,  Elapsed-Time: 3.75 seconds
# Palaven.SaveResponse. InstructionId: 4029,  Elapsed-Time: 0.83 seconds
# 5 - LLM-ChatCompletion. InstructionId: 4031,  Elapsed-Time: 5.60 seconds
# Palaven.SaveResponse. InstructionId: 4031,  Elapsed-Time: 0.83 seconds
# 6 - LLM-ChatCompletion. InstructionId: 4033,  Elapsed-Time: 3.96 seconds
# Palaven.SaveResponse. InstructionId: 4033,  Elapsed-Time: 0.85 seconds
# 7 - LLM-ChatCompletion. InstructionId: 4035,  Elapsed-Time: 3.74 seconds
# Palaven.SaveResponse. InstructionId: 4035,  Elapsed-Time: 0.85 seconds
# 8 - LLM-ChatCompletion. InstructionId: 4037,  Elapsed-Time: 3.31 seconds
# Palaven.SaveResponse. InstructionId: 4037,  Elapsed-Time: 0.84 seconds
# 9 - LLM-ChatCompletion. InstructionId: 4039,  Elapsed-Time: 4.16 seconds
# Palaven.SaveResponse. InstructionId: 4039,  Elapsed-Time: 0.89 seconds
# 10 - LLM-ChatCompletion. InstructionId: 4049,  Elapsed-Time: 6.47 seconds
# Palaven.SaveResponse. InstructionId: 4049,  Elapsed-Time: 0.83 seconds
# 11 - LLM-ChatCompletion. InstructionId: 4051,  Elapsed-Time: 2.24 seconds
# Palaven.SaveResponse. InstructionId: 4051,  Elapsed-Time: 0.84 seconds
# 12 - LLM-ChatCompletion. InstructionId: 4053,  Elapsed-Time: 2.15 seconds
# Palaven.SaveResponse. InstructionId: 4053,  Elapsed-Time: 0.83 seconds
# 13 - LLM-ChatCompletion. InstructionId: 4055,  Elapsed-Time: 3.88 seconds
# Palaven.SaveResponse. InstructionId: 4055,  Elapsed-Time: 0.85 seconds
# 14 - LLM-ChatCompletion. InstructionId: 4057,  Elapsed-Time: 2.96 seconds
# Palaven.SaveResponse. InstructionId: 4057,  Elapsed-Time: 0.82 seconds
# 15 - LLM-ChatCompletion. InstructionId: 4059,  Elapsed-Time: 2.18 seconds
# Palaven.SaveResponse. InstructionId: 4059,  Elapsed-Time: 0.84 seconds
# 16 - LLM-ChatCompletion. InstructionId: 4061,  Elapsed-Time: 1.89 seconds
# Palaven.SaveResponse. InstructionId: 4061,  Elapsed-Time: 0.82 seconds
# 17 - LLM-ChatCompletion. InstructionId: 4063,  Elapsed-Time: 2.05 seconds
# Palaven.SaveResponse. InstructionId: 4063,  Elapsed-Time: 0.84 seconds
# 18 - LLM-ChatCompletion. InstructionId: 4073,  Elapsed-Time: 2.25 seconds
# Palaven.SaveResponse. InstructionId: 4073,  Elapsed-Time: 0.83 seconds
# 19 - LLM-ChatCompletion. InstructionId: 4075,  Elapsed-Time: 3.52 seconds
# Palaven.SaveResponse. InstructionId: 4075,  Elapsed-Time: 0.82 seconds
# 20 - LLM-ChatCompletion. InstructionId: 4077,  Elapsed-Time: 3.38 seconds
# Palaven.SaveResponse. InstructionId: 4077,  Elapsed-Time: 0.84 seconds
# 21 - LLM-ChatCompletion. InstructionId: 4079,  Elapsed-Time: 1.42 seconds
# Palaven.SaveResponse. InstructionId: 4079,  Elapsed-Time: 0.82 seconds
# 22 - LLM-ChatCompletion. InstructionId: 4081,  Elapsed-Time: 3.22 seconds
# Palaven.SaveResponse. InstructionId: 4081,  Elapsed-Time: 0.83 seconds
# 23 - LLM-ChatCompletion. InstructionId: 4083,  Elapsed-Time: 3.10 seconds
# Palaven.SaveResponse. InstructionId: 4083,  Elapsed-Time: 0.84 seconds
# 24 - LLM-ChatCompletion. InstructionId: 4085,  Elapsed-Time: 4.94 seconds
# Palaven.SaveResponse. InstructionId: 4085,  Elapsed-Time: 0.82 seconds
# 25 - LLM-ChatCompletion. InstructionId: 4087,  Elapsed-Time: 2.41 seconds
# Palaven.SaveResponse. InstructionId: 4087,  Elapsed-Time: 0.83 seconds
# 26 - LLM-ChatCompletion. InstructionId: 4097,  Elapsed-Time: 2.66 seconds
# Palaven.SaveResponse. InstructionId: 4097,  Elapsed-Time: 0.85 seconds
# 27 - LLM-ChatCompletion. InstructionId: 4099,  Elapsed-Time: 3.06 seconds
# Palaven.SaveResponse. InstructionId: 4099,  Elapsed-Time: 0.82 seconds
# 28 - LLM-ChatCompletion. InstructionId: 4101,  Elapsed-Time: 4.55 seconds
# Palaven.SaveResponse. InstructionId: 4101,  Elapsed-Time: 0.84 seconds
# 29 - LLM-ChatCompletion. InstructionId: 4103,  Elapsed-Time: 3.69 seconds
# Palaven.SaveResponse. InstructionId: 4103,  Elapsed-Time: 0.84 seconds
# 30 - LLM-ChatCompletion. InstructionId: 4105,  Elapsed-Time: 4.56 seconds
# Palaven.SaveResponse. InstructionId: 4105,  Elapsed-Time: 0.85 seconds
# 31 - LLM-ChatCompletion. InstructionId: 4107,  Elapsed-Time: 2.69 seconds
# Palaven.SaveResponse. InstructionId: 4107,  Elapsed-Time: 0.85 seconds
# 32 - LLM-ChatCompletion. InstructionId: 4109,  Elapsed-Time: 3.24 seconds
# Palaven.SaveResponse. InstructionId: 4109,  Elapsed-Time: 0.82 seconds
# 33 - LLM-ChatCompletion. InstructionId: 4111,  Elapsed-Time: 2.90 seconds
# Palaven.SaveResponse. InstructionId: 4111,  Elapsed-Time: 0.85 seconds
# 34 - LLM-ChatCompletion. InstructionId: 4113,  Elapsed-Time: 2.88 seconds
# Palaven.SaveResponse. InstructionId: 4113,  Elapsed-Time: 0.86 seconds
# 35 - LLM-ChatCompletion. InstructionId: 4124,  Elapsed-Time: 2.48 seconds
# Palaven.SaveResponse. InstructionId: 4124,  Elapsed-Time: 0.83 seconds
# 36 - LLM-ChatCompletion. InstructionId: 4126,  Elapsed-Time: 7.61 seconds
# Palaven.SaveResponse. InstructionId: 4126,  Elapsed-Time: 0.85 seconds
# 37 - LLM-ChatCompletion. InstructionId: 4128,  Elapsed-Time: 4.43 seconds
# Palaven.SaveResponse. InstructionId: 4128,  Elapsed-Time: 0.84 seconds
# 38 - LLM-ChatCompletion. InstructionId: 4130,  Elapsed-Time: 7.96 seconds
# Palaven.SaveResponse. InstructionId: 4130,  Elapsed-Time: 0.86 seconds
# 39 - LLM-ChatCompletion. InstructionId: 4132,  Elapsed-Time: 7.56 seconds
# Palaven.SaveResponse. InstructionId: 4132,  Elapsed-Time: 0.84 seconds
# 40 - LLM-ChatCompletion. InstructionId: 4134,  Elapsed-Time: 7.93 seconds
# Palaven.SaveResponse. InstructionId: 4134,  Elapsed-Time: 0.83 seconds
# 41 - LLM-ChatCompletion. InstructionId: 4136,  Elapsed-Time: 7.90 seconds
# Palaven.SaveResponse. InstructionId: 4136,  Elapsed-Time: 0.85 seconds
# 42 - LLM-ChatCompletion. InstructionId: 4138,  Elapsed-Time: 1.68 seconds
# Palaven.SaveResponse. InstructionId: 4138,  Elapsed-Time: 0.83 seconds
# 43 - LLM-ChatCompletion. InstructionId: 4147,  Elapsed-Time: 9.21 seconds
# Palaven.SaveResponse. InstructionId: 4147,  Elapsed-Time: 0.86 seconds
# 44 - LLM-ChatCompletion. InstructionId: 4149,  Elapsed-Time: 2.60 seconds
# Palaven.SaveResponse. InstructionId: 4149,  Elapsed-Time: 0.82 seconds
# 45 - LLM-ChatCompletion. InstructionId: 4151,  Elapsed-Time: 2.96 seconds
# Palaven.SaveResponse. InstructionId: 4151,  Elapsed-Time: 0.82 seconds
# 46 - LLM-ChatCompletion. InstructionId: 4153,  Elapsed-Time: 3.36 seconds
# Palaven.SaveResponse. InstructionId: 4153,  Elapsed-Time: 0.85 seconds
# 47 - LLM-ChatCompletion. InstructionId: 4155,  Elapsed-Time: 1.99 seconds
# Palaven.SaveResponse. InstructionId: 4155,  Elapsed-Time: 0.86 seconds
# 48 - LLM-ChatCompletion. InstructionId: 4157,  Elapsed-Time: 4.08 seconds
# Palaven.SaveResponse. InstructionId: 4157,  Elapsed-Time: 0.83 seconds
# 49 - LLM-ChatCompletion. InstructionId: 4159,  Elapsed-Time: 2.21 seconds
# Palaven.SaveResponse. InstructionId: 4159,  Elapsed-Time: 0.82 seconds
# 50 - LLM-ChatCompletion. InstructionId: 4161,  Elapsed-Time: 3.23 seconds
# Palaven.SaveResponse. InstructionId: 4161,  Elapsed-Time: 0.82 seconds
# Start fetching batch 3
# Start fetching batch done...
# <ipython-input-8-9ad68d3380dc>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '¿Qué se incluye en la última declaración del ejercicio de liquidación de una sociedad?' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[instruction_id, 'instruction'] = instruction
# 1 - LLM-ChatCompletion. InstructionId: 4163,  Elapsed-Time: 1.65 seconds
# Palaven.SaveResponse. InstructionId: 4163,  Elapsed-Time: 0.85 seconds
# 2 - LLM-ChatCompletion. InstructionId: 4165,  Elapsed-Time: 1.89 seconds
# Palaven.SaveResponse. InstructionId: 4165,  Elapsed-Time: 0.84 seconds
# 3 - LLM-ChatCompletion. InstructionId: 4175,  Elapsed-Time: 9.17 seconds
# Palaven.SaveResponse. InstructionId: 4175,  Elapsed-Time: 0.85 seconds
# 4 - LLM-ChatCompletion. InstructionId: 4177,  Elapsed-Time: 3.59 seconds
# Palaven.SaveResponse. InstructionId: 4177,  Elapsed-Time: 0.83 seconds
# 5 - LLM-ChatCompletion. InstructionId: 4179,  Elapsed-Time: 4.55 seconds
# Palaven.SaveResponse. InstructionId: 4179,  Elapsed-Time: 0.86 seconds
# 6 - LLM-ChatCompletion. InstructionId: 4181,  Elapsed-Time: 3.98 seconds
# Palaven.SaveResponse. InstructionId: 4181,  Elapsed-Time: 0.83 seconds
# 7 - LLM-ChatCompletion. InstructionId: 4183,  Elapsed-Time: 4.67 seconds
# Palaven.SaveResponse. InstructionId: 4183,  Elapsed-Time: 0.88 seconds
# 8 - LLM-ChatCompletion. InstructionId: 4185,  Elapsed-Time: 3.38 seconds
# Palaven.SaveResponse. InstructionId: 4185,  Elapsed-Time: 0.83 seconds
# 9 - LLM-ChatCompletion. InstructionId: 4187,  Elapsed-Time: 3.59 seconds
# Palaven.SaveResponse. InstructionId: 4187,  Elapsed-Time: 0.84 seconds
# 10 - LLM-ChatCompletion. InstructionId: 4189,  Elapsed-Time: 3.30 seconds
# Palaven.SaveResponse. InstructionId: 4189,  Elapsed-Time: 0.85 seconds
# 11 - LLM-ChatCompletion. InstructionId: 4199,  Elapsed-Time: 2.85 seconds
# Palaven.SaveResponse. InstructionId: 4199,  Elapsed-Time: 0.83 seconds
# 12 - LLM-ChatCompletion. InstructionId: 4201,  Elapsed-Time: 6.65 seconds
# Palaven.SaveResponse. InstructionId: 4201,  Elapsed-Time: 0.84 seconds
# 13 - LLM-ChatCompletion. InstructionId: 4203,  Elapsed-Time: 4.16 seconds
# Palaven.SaveResponse. InstructionId: 4203,  Elapsed-Time: 0.85 seconds
# 14 - LLM-ChatCompletion. InstructionId: 4205,  Elapsed-Time: 4.60 seconds
# Palaven.SaveResponse. InstructionId: 4205,  Elapsed-Time: 0.84 seconds
# 15 - LLM-ChatCompletion. InstructionId: 4207,  Elapsed-Time: 5.75 seconds
# Palaven.SaveResponse. InstructionId: 4207,  Elapsed-Time: 0.85 seconds
# 16 - LLM-ChatCompletion. InstructionId: 4209,  Elapsed-Time: 5.71 seconds
# Palaven.SaveResponse. InstructionId: 4209,  Elapsed-Time: 0.83 seconds
# 17 - LLM-ChatCompletion. InstructionId: 4211,  Elapsed-Time: 6.22 seconds
# Palaven.SaveResponse. InstructionId: 4211,  Elapsed-Time: 0.84 seconds
# 18 - LLM-ChatCompletion. InstructionId: 4213,  Elapsed-Time: 6.32 seconds
# Palaven.SaveResponse. InstructionId: 4213,  Elapsed-Time: 0.86 seconds
# 19 - LLM-ChatCompletion. InstructionId: 4223,  Elapsed-Time: 6.95 seconds
# Palaven.SaveResponse. InstructionId: 4223,  Elapsed-Time: 0.85 seconds
# 20 - LLM-ChatCompletion. InstructionId: 4225,  Elapsed-Time: 2.95 seconds
# Palaven.SaveResponse. InstructionId: 4225,  Elapsed-Time: 0.84 seconds
# 21 - LLM-ChatCompletion. InstructionId: 4227,  Elapsed-Time: 3.27 seconds
# Palaven.SaveResponse. InstructionId: 4227,  Elapsed-Time: 0.82 seconds
# 22 - LLM-ChatCompletion. InstructionId: 4229,  Elapsed-Time: 2.91 seconds
# Palaven.SaveResponse. InstructionId: 4229,  Elapsed-Time: 0.83 seconds
# 23 - LLM-ChatCompletion. InstructionId: 4231,  Elapsed-Time: 2.99 seconds
# Palaven.SaveResponse. InstructionId: 4231,  Elapsed-Time: 0.86 seconds
# 24 - LLM-ChatCompletion. InstructionId: 4237,  Elapsed-Time: 4.23 seconds
# Palaven.SaveResponse. InstructionId: 4237,  Elapsed-Time: 0.85 seconds
# 25 - LLM-ChatCompletion. InstructionId: 4239,  Elapsed-Time: 3.45 seconds
# Palaven.SaveResponse. InstructionId: 4239,  Elapsed-Time: 0.83 seconds
# 26 - LLM-ChatCompletion. InstructionId: 4241,  Elapsed-Time: 4.02 seconds
# Palaven.SaveResponse. InstructionId: 4241,  Elapsed-Time: 0.84 seconds
# 27 - LLM-ChatCompletion. InstructionId: 4243,  Elapsed-Time: 2.78 seconds
# Palaven.SaveResponse. InstructionId: 4243,  Elapsed-Time: 0.85 seconds
# 28 - LLM-ChatCompletion. InstructionId: 4245,  Elapsed-Time: 3.28 seconds
# Palaven.SaveResponse. InstructionId: 4245,  Elapsed-Time: 0.84 seconds
# 29 - LLM-ChatCompletion. InstructionId: 4247,  Elapsed-Time: 6.23 seconds
# Palaven.SaveResponse. InstructionId: 4247,  Elapsed-Time: 0.84 seconds
# 30 - LLM-ChatCompletion. InstructionId: 4252,  Elapsed-Time: 8.32 seconds
# Palaven.SaveResponse. InstructionId: 4252,  Elapsed-Time: 0.87 seconds
# 31 - LLM-ChatCompletion. InstructionId: 4254,  Elapsed-Time: 2.13 seconds
# Palaven.SaveResponse. InstructionId: 4254,  Elapsed-Time: 0.85 seconds
# 32 - LLM-ChatCompletion. InstructionId: 4256,  Elapsed-Time: 3.86 seconds
# Palaven.SaveResponse. InstructionId: 4256,  Elapsed-Time: 0.89 seconds
# 33 - LLM-ChatCompletion. InstructionId: 4258,  Elapsed-Time: 7.30 seconds
# Palaven.SaveResponse. InstructionId: 4258,  Elapsed-Time: 0.83 seconds
# 34 - LLM-ChatCompletion. InstructionId: 4260,  Elapsed-Time: 3.43 seconds
# Palaven.SaveResponse. InstructionId: 4260,  Elapsed-Time: 0.84 seconds
# 35 - LLM-ChatCompletion. InstructionId: 4262,  Elapsed-Time: 1.93 seconds
# Palaven.SaveResponse. InstructionId: 4262,  Elapsed-Time: 0.85 seconds
# 36 - LLM-ChatCompletion. InstructionId: 4264,  Elapsed-Time: 5.24 seconds
# Palaven.SaveResponse. InstructionId: 4264,  Elapsed-Time: 0.85 seconds
# 37 - LLM-ChatCompletion. InstructionId: 4266,  Elapsed-Time: 6.50 seconds
# Palaven.SaveResponse. InstructionId: 4266,  Elapsed-Time: 0.83 seconds
# 38 - LLM-ChatCompletion. InstructionId: 4274,  Elapsed-Time: 6.60 seconds
# Palaven.SaveResponse. InstructionId: 4274,  Elapsed-Time: 0.86 seconds
# 39 - LLM-ChatCompletion. InstructionId: 4276,  Elapsed-Time: 3.50 seconds
# Palaven.SaveResponse. InstructionId: 4276,  Elapsed-Time: 0.83 seconds
# 40 - LLM-ChatCompletion. InstructionId: 4278,  Elapsed-Time: 2.86 seconds
# Palaven.SaveResponse. InstructionId: 4278,  Elapsed-Time: 0.88 seconds
# 41 - LLM-ChatCompletion. InstructionId: 4280,  Elapsed-Time: 3.92 seconds
# Palaven.SaveResponse. InstructionId: 4280,  Elapsed-Time: 0.85 seconds
# 42 - LLM-ChatCompletion. InstructionId: 4282,  Elapsed-Time: 4.74 seconds
# Palaven.SaveResponse. InstructionId: 4282,  Elapsed-Time: 0.82 seconds
# 43 - LLM-ChatCompletion. InstructionId: 4284,  Elapsed-Time: 3.22 seconds
# Palaven.SaveResponse. InstructionId: 4284,  Elapsed-Time: 0.85 seconds
# 44 - LLM-ChatCompletion. InstructionId: 4286,  Elapsed-Time: 3.59 seconds
# Palaven.SaveResponse. InstructionId: 4286,  Elapsed-Time: 0.83 seconds
# 45 - LLM-ChatCompletion. InstructionId: 4288,  Elapsed-Time: 3.03 seconds
# Palaven.SaveResponse. InstructionId: 4288,  Elapsed-Time: 0.85 seconds
# 46 - LLM-ChatCompletion. InstructionId: 4298,  Elapsed-Time: 2.94 seconds
# Palaven.SaveResponse. InstructionId: 4298,  Elapsed-Time: 0.85 seconds
# 47 - LLM-ChatCompletion. InstructionId: 4300,  Elapsed-Time: 2.67 seconds
# Palaven.SaveResponse. InstructionId: 4300,  Elapsed-Time: 0.85 seconds
# 48 - LLM-ChatCompletion. InstructionId: 4302,  Elapsed-Time: 2.72 seconds
# Palaven.SaveResponse. InstructionId: 4302,  Elapsed-Time: 0.82 seconds
# 49 - LLM-ChatCompletion. InstructionId: 4304,  Elapsed-Time: 3.34 seconds
# Palaven.SaveResponse. InstructionId: 4304,  Elapsed-Time: 0.82 seconds
# 50 - LLM-ChatCompletion. InstructionId: 4306,  Elapsed-Time: 2.65 seconds
# Palaven.SaveResponse. InstructionId: 4306,  Elapsed-Time: 0.85 seconds
# Start fetching batch 4
# Start fetching batch done...
# <ipython-input-8-9ad68d3380dc>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '¿Qué se debe considerar al calcular la ganancia por la enajenación de acciones y certificados de depósito de bienes o mercancías según la Ley del Impuesto Sobre la Renta del 2024?' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[instruction_id, 'instruction'] = instruction
# 1 - LLM-ChatCompletion. InstructionId: 4308,  Elapsed-Time: 1.88 seconds
# Palaven.SaveResponse. InstructionId: 4308,  Elapsed-Time: 0.84 seconds
# 2 - LLM-ChatCompletion. InstructionId: 4310,  Elapsed-Time: 1.90 seconds
# Palaven.SaveResponse. InstructionId: 4310,  Elapsed-Time: 0.82 seconds
# 3 - LLM-ChatCompletion. InstructionId: 4318,  Elapsed-Time: 4.72 seconds
# Palaven.SaveResponse. InstructionId: 4318,  Elapsed-Time: 0.83 seconds
# 4 - LLM-ChatCompletion. InstructionId: 4320,  Elapsed-Time: 5.31 seconds
# Palaven.SaveResponse. InstructionId: 4320,  Elapsed-Time: 0.83 seconds
# 5 - LLM-ChatCompletion. InstructionId: 4322,  Elapsed-Time: 4.87 seconds
# Palaven.SaveResponse. InstructionId: 4322,  Elapsed-Time: 0.84 seconds
# 6 - LLM-ChatCompletion. InstructionId: 4324,  Elapsed-Time: 7.31 seconds
# Palaven.SaveResponse. InstructionId: 4324,  Elapsed-Time: 0.85 seconds
# 7 - LLM-ChatCompletion. InstructionId: 4326,  Elapsed-Time: 5.06 seconds
# Palaven.SaveResponse. InstructionId: 4326,  Elapsed-Time: 0.85 seconds
# 8 - LLM-ChatCompletion. InstructionId: 4328,  Elapsed-Time: 7.09 seconds
# Palaven.SaveResponse. InstructionId: 4328,  Elapsed-Time: 0.86 seconds
# 9 - LLM-ChatCompletion. InstructionId: 4330,  Elapsed-Time: 5.91 seconds
# Palaven.SaveResponse. InstructionId: 4330,  Elapsed-Time: 0.84 seconds
# 10 - LLM-ChatCompletion. InstructionId: 4332,  Elapsed-Time: 5.29 seconds
# Palaven.SaveResponse. InstructionId: 4332,  Elapsed-Time: 0.84 seconds
# 11 - LLM-ChatCompletion. InstructionId: 4342,  Elapsed-Time: 5.33 seconds
# Palaven.SaveResponse. InstructionId: 4342,  Elapsed-Time: 0.84 seconds
# 12 - LLM-ChatCompletion. InstructionId: 4344,  Elapsed-Time: 2.68 seconds
# Palaven.SaveResponse. InstructionId: 4344,  Elapsed-Time: 0.85 seconds
# 13 - LLM-ChatCompletion. InstructionId: 4346,  Elapsed-Time: 5.46 seconds
# Palaven.SaveResponse. InstructionId: 4346,  Elapsed-Time: 0.86 seconds
# 14 - LLM-ChatCompletion. InstructionId: 4348,  Elapsed-Time: 3.70 seconds
# Palaven.SaveResponse. InstructionId: 4348,  Elapsed-Time: 0.85 seconds
# 15 - LLM-ChatCompletion. InstructionId: 4350,  Elapsed-Time: 2.48 seconds
# Palaven.SaveResponse. InstructionId: 4350,  Elapsed-Time: 0.82 seconds
# 16 - LLM-ChatCompletion. InstructionId: 4352,  Elapsed-Time: 2.49 seconds
# Palaven.SaveResponse. InstructionId: 4352,  Elapsed-Time: 0.85 seconds
# 17 - LLM-ChatCompletion. InstructionId: 4354,  Elapsed-Time: 2.65 seconds
# Palaven.SaveResponse. InstructionId: 4354,  Elapsed-Time: 0.82 seconds
# 18 - LLM-ChatCompletion. InstructionId: 4356,  Elapsed-Time: 4.09 seconds
# Palaven.SaveResponse. InstructionId: 4356,  Elapsed-Time: 0.87 seconds
# 19 - LLM-ChatCompletion. InstructionId: 4366,  Elapsed-Time: 2.45 seconds
# Palaven.SaveResponse. InstructionId: 4366,  Elapsed-Time: 0.82 seconds
# 20 - LLM-ChatCompletion. InstructionId: 4368,  Elapsed-Time: 3.55 seconds
# Palaven.SaveResponse. InstructionId: 4368,  Elapsed-Time: 0.83 seconds
# 21 - LLM-ChatCompletion. InstructionId: 4370,  Elapsed-Time: 3.32 seconds
# Palaven.SaveResponse. InstructionId: 4370,  Elapsed-Time: 0.86 seconds
# 22 - LLM-ChatCompletion. InstructionId: 4372,  Elapsed-Time: 3.07 seconds
# Palaven.SaveResponse. InstructionId: 4372,  Elapsed-Time: 0.83 seconds
# 23 - LLM-ChatCompletion. InstructionId: 4374,  Elapsed-Time: 3.41 seconds
# Palaven.SaveResponse. InstructionId: 4374,  Elapsed-Time: 0.86 seconds
# 24 - LLM-ChatCompletion. InstructionId: 4376,  Elapsed-Time: 3.41 seconds
# Palaven.SaveResponse. InstructionId: 4376,  Elapsed-Time: 0.87 seconds
# 25 - LLM-ChatCompletion. InstructionId: 4378,  Elapsed-Time: 3.58 seconds
# Palaven.SaveResponse. InstructionId: 4378,  Elapsed-Time: 0.85 seconds
# 26 - LLM-ChatCompletion. InstructionId: 4380,  Elapsed-Time: 6.63 seconds
# Palaven.SaveResponse. InstructionId: 4380,  Elapsed-Time: 0.86 seconds
# 27 - LLM-ChatCompletion. InstructionId: 4388,  Elapsed-Time: 2.60 seconds
# Palaven.SaveResponse. InstructionId: 4388,  Elapsed-Time: 0.84 seconds
# 28 - LLM-ChatCompletion. InstructionId: 4390,  Elapsed-Time: 4.85 seconds
# Palaven.SaveResponse. InstructionId: 4390,  Elapsed-Time: 0.85 seconds
# 29 - LLM-ChatCompletion. InstructionId: 4392,  Elapsed-Time: 6.11 seconds
# Palaven.SaveResponse. InstructionId: 4392,  Elapsed-Time: 0.86 seconds
# 30 - LLM-ChatCompletion. InstructionId: 4394,  Elapsed-Time: 4.58 seconds
# Palaven.SaveResponse. InstructionId: 4394,  Elapsed-Time: 0.86 seconds
# 31 - LLM-ChatCompletion. InstructionId: 4396,  Elapsed-Time: 6.17 seconds
# Palaven.SaveResponse. InstructionId: 4396,  Elapsed-Time: 0.85 seconds
# 32 - LLM-ChatCompletion. InstructionId: 4398,  Elapsed-Time: 4.28 seconds
# Palaven.SaveResponse. InstructionId: 4398,  Elapsed-Time: 0.83 seconds
# 33 - LLM-ChatCompletion. InstructionId: 4400,  Elapsed-Time: 4.89 seconds
# Palaven.SaveResponse. InstructionId: 4400,  Elapsed-Time: 0.85 seconds
# 34 - LLM-ChatCompletion. InstructionId: 4402,  Elapsed-Time: 8.66 seconds
# Palaven.SaveResponse. InstructionId: 4402,  Elapsed-Time: 0.86 seconds
# 35 - LLM-ChatCompletion. InstructionId: 4404,  Elapsed-Time: 7.53 seconds
# Palaven.SaveResponse. InstructionId: 4404,  Elapsed-Time: 0.83 seconds
# 36 - LLM-ChatCompletion. InstructionId: 4413,  Elapsed-Time: 6.49 seconds
# Palaven.SaveResponse. InstructionId: 4413,  Elapsed-Time: 0.84 seconds
# 37 - LLM-ChatCompletion. InstructionId: 4415,  Elapsed-Time: 4.63 seconds
# Palaven.SaveResponse. InstructionId: 4415,  Elapsed-Time: 0.87 seconds
# 38 - LLM-ChatCompletion. InstructionId: 4417,  Elapsed-Time: 5.94 seconds
# Palaven.SaveResponse. InstructionId: 4417,  Elapsed-Time: 0.85 seconds
# 39 - LLM-ChatCompletion. InstructionId: 4419,  Elapsed-Time: 2.89 seconds
# Palaven.SaveResponse. InstructionId: 4419,  Elapsed-Time: 0.85 seconds
# 40 - LLM-ChatCompletion. InstructionId: 4421,  Elapsed-Time: 2.98 seconds
# Palaven.SaveResponse. InstructionId: 4421,  Elapsed-Time: 0.85 seconds
# 41 - LLM-ChatCompletion. InstructionId: 4423,  Elapsed-Time: 2.55 seconds
# Palaven.SaveResponse. InstructionId: 4423,  Elapsed-Time: 0.86 seconds
# 42 - LLM-ChatCompletion. InstructionId: 4425,  Elapsed-Time: 2.47 seconds
# Palaven.SaveResponse. InstructionId: 4425,  Elapsed-Time: 0.83 seconds
# 43 - LLM-ChatCompletion. InstructionId: 4427,  Elapsed-Time: 2.72 seconds
# Palaven.SaveResponse. InstructionId: 4427,  Elapsed-Time: 0.82 seconds
# 44 - LLM-ChatCompletion. InstructionId: 4435,  Elapsed-Time: 4.97 seconds
# Palaven.SaveResponse. InstructionId: 4435,  Elapsed-Time: 0.83 seconds
# 45 - LLM-ChatCompletion. InstructionId: 4437,  Elapsed-Time: 3.40 seconds
# Palaven.SaveResponse. InstructionId: 4437,  Elapsed-Time: 0.83 seconds
# 46 - LLM-ChatCompletion. InstructionId: 4439,  Elapsed-Time: 3.60 seconds
# Palaven.SaveResponse. InstructionId: 4439,  Elapsed-Time: 0.82 seconds
# 47 - LLM-ChatCompletion. InstructionId: 4441,  Elapsed-Time: 1.59 seconds
# Palaven.SaveResponse. InstructionId: 4441,  Elapsed-Time: 0.86 seconds
# 48 - LLM-ChatCompletion. InstructionId: 4443,  Elapsed-Time: 3.96 seconds
# Palaven.SaveResponse. InstructionId: 4443,  Elapsed-Time: 0.84 seconds
# 49 - LLM-ChatCompletion. InstructionId: 4445,  Elapsed-Time: 3.00 seconds
# Palaven.SaveResponse. InstructionId: 4445,  Elapsed-Time: 0.85 seconds
# 50 - LLM-ChatCompletion. InstructionId: 4447,  Elapsed-Time: 2.82 seconds
# Palaven.SaveResponse. InstructionId: 4447,  Elapsed-Time: 0.86 seconds
# Start fetching batch 5
# Start fetching batch done...
# <ipython-input-8-9ad68d3380dc>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '¿Qué tipo de remesas no son deducibles para un establecimiento permanente en México de una empresa residente en el extranjero?' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[instruction_id, 'instruction'] = instruction
# 1 - LLM-ChatCompletion. InstructionId: 4449,  Elapsed-Time: 3.99 seconds
# Palaven.SaveResponse. InstructionId: 4449,  Elapsed-Time: 0.84 seconds
# 2 - LLM-ChatCompletion. InstructionId: 4459,  Elapsed-Time: 6.54 seconds
# Palaven.SaveResponse. InstructionId: 4459,  Elapsed-Time: 0.82 seconds
# 3 - LLM-ChatCompletion. InstructionId: 4461,  Elapsed-Time: 2.60 seconds
# Palaven.SaveResponse. InstructionId: 4461,  Elapsed-Time: 0.85 seconds
# 4 - LLM-ChatCompletion. InstructionId: 4463,  Elapsed-Time: 3.25 seconds
# Palaven.SaveResponse. InstructionId: 4463,  Elapsed-Time: 0.85 seconds
# 5 - LLM-ChatCompletion. InstructionId: 4465,  Elapsed-Time: 2.91 seconds
# Palaven.SaveResponse. InstructionId: 4465,  Elapsed-Time: 0.86 seconds
# 6 - LLM-ChatCompletion. InstructionId: 4467,  Elapsed-Time: 3.38 seconds
# Palaven.SaveResponse. InstructionId: 4467,  Elapsed-Time: 0.85 seconds
# 7 - LLM-ChatCompletion. InstructionId: 4469,  Elapsed-Time: 2.48 seconds
# Palaven.SaveResponse. InstructionId: 4469,  Elapsed-Time: 0.82 seconds
# 8 - LLM-ChatCompletion. InstructionId: 4471,  Elapsed-Time: 2.59 seconds
# Palaven.SaveResponse. InstructionId: 4471,  Elapsed-Time: 0.85 seconds
# 9 - LLM-ChatCompletion. InstructionId: 4478,  Elapsed-Time: 3.07 seconds
# Palaven.SaveResponse. InstructionId: 4478,  Elapsed-Time: 0.82 seconds
# 10 - LLM-ChatCompletion. InstructionId: 4480,  Elapsed-Time: 3.50 seconds
# Palaven.SaveResponse. InstructionId: 4480,  Elapsed-Time: 0.85 seconds
# 11 - LLM-ChatCompletion. InstructionId: 4482,  Elapsed-Time: 3.61 seconds
# Palaven.SaveResponse. InstructionId: 4482,  Elapsed-Time: 0.86 seconds
# 12 - LLM-ChatCompletion. InstructionId: 4484,  Elapsed-Time: 5.48 seconds
# Palaven.SaveResponse. InstructionId: 4484,  Elapsed-Time: 0.85 seconds
# 13 - LLM-ChatCompletion. InstructionId: 4486,  Elapsed-Time: 3.29 seconds
# Palaven.SaveResponse. InstructionId: 4486,  Elapsed-Time: 0.84 seconds
# 14 - LLM-ChatCompletion. InstructionId: 4488,  Elapsed-Time: 5.57 seconds
# Palaven.SaveResponse. InstructionId: 4488,  Elapsed-Time: 0.82 seconds
# 15 - LLM-ChatCompletion. InstructionId: 4490,  Elapsed-Time: 5.83 seconds
# Palaven.SaveResponse. InstructionId: 4490,  Elapsed-Time: 0.86 seconds
# 16 - LLM-ChatCompletion. InstructionId: 4492,  Elapsed-Time: 3.56 seconds
# Palaven.SaveResponse. InstructionId: 4492,  Elapsed-Time: 0.84 seconds
# 17 - LLM-ChatCompletion. InstructionId: 4502,  Elapsed-Time: 7.38 seconds
# Palaven.SaveResponse. InstructionId: 4502,  Elapsed-Time: 0.86 seconds
# 18 - LLM-ChatCompletion. InstructionId: 4504,  Elapsed-Time: 3.83 seconds
# Palaven.SaveResponse. InstructionId: 4504,  Elapsed-Time: 0.88 seconds
# 19 - LLM-ChatCompletion. InstructionId: 4506,  Elapsed-Time: 3.61 seconds
# Palaven.SaveResponse. InstructionId: 4506,  Elapsed-Time: 0.84 seconds
# 20 - LLM-ChatCompletion. InstructionId: 4508,  Elapsed-Time: 3.56 seconds
# Palaven.SaveResponse. InstructionId: 4508,  Elapsed-Time: 0.84 seconds
# 21 - LLM-ChatCompletion. InstructionId: 4510,  Elapsed-Time: 3.00 seconds
# Palaven.SaveResponse. InstructionId: 4510,  Elapsed-Time: 0.85 seconds
# 22 - LLM-ChatCompletion. InstructionId: 4512,  Elapsed-Time: 3.09 seconds
# Palaven.SaveResponse. InstructionId: 4512,  Elapsed-Time: 0.83 seconds
# 23 - LLM-ChatCompletion. InstructionId: 4514,  Elapsed-Time: 3.85 seconds
# Palaven.SaveResponse. InstructionId: 4514,  Elapsed-Time: 0.84 seconds
# 24 - LLM-ChatCompletion. InstructionId: 4516,  Elapsed-Time: 3.21 seconds
# Palaven.SaveResponse. InstructionId: 4516,  Elapsed-Time: 0.81 seconds
# 25 - LLM-ChatCompletion. InstructionId: 4525,  Elapsed-Time: 8.66 seconds
# Palaven.SaveResponse. InstructionId: 4525,  Elapsed-Time: 0.87 seconds
# 26 - LLM-ChatCompletion. InstructionId: 4527,  Elapsed-Time: 2.84 seconds
# Palaven.SaveResponse. InstructionId: 4527,  Elapsed-Time: 0.82 seconds
# 27 - LLM-ChatCompletion. InstructionId: 4529,  Elapsed-Time: 1.23 seconds
# Palaven.SaveResponse. InstructionId: 4529,  Elapsed-Time: 0.88 seconds
# 28 - LLM-ChatCompletion. InstructionId: 4531,  Elapsed-Time: 2.63 seconds
# Palaven.SaveResponse. InstructionId: 4531,  Elapsed-Time: 0.86 seconds
# 29 - LLM-ChatCompletion. InstructionId: 4533,  Elapsed-Time: 1.71 seconds
# Palaven.SaveResponse. InstructionId: 4533,  Elapsed-Time: 0.83 seconds
# 30 - LLM-ChatCompletion. InstructionId: 4535,  Elapsed-Time: 2.16 seconds
# Palaven.SaveResponse. InstructionId: 4535,  Elapsed-Time: 0.85 seconds
# 31 - LLM-ChatCompletion. InstructionId: 4537,  Elapsed-Time: 1.79 seconds
# Palaven.SaveResponse. InstructionId: 4537,  Elapsed-Time: 0.88 seconds
# 32 - LLM-ChatCompletion. InstructionId: 4539,  Elapsed-Time: 4.13 seconds
# Palaven.SaveResponse. InstructionId: 4539,  Elapsed-Time: 0.85 seconds
# 33 - LLM-ChatCompletion. InstructionId: 4548,  Elapsed-Time: 4.12 seconds
# Palaven.SaveResponse. InstructionId: 4548,  Elapsed-Time: 0.85 seconds
# 34 - LLM-ChatCompletion. InstructionId: 4550,  Elapsed-Time: 3.90 seconds
# Palaven.SaveResponse. InstructionId: 4550,  Elapsed-Time: 0.83 seconds
# 35 - LLM-ChatCompletion. InstructionId: 4552,  Elapsed-Time: 2.43 seconds
# Palaven.SaveResponse. InstructionId: 4552,  Elapsed-Time: 0.84 seconds
# 36 - LLM-ChatCompletion. InstructionId: 4554,  Elapsed-Time: 2.74 seconds
# Palaven.SaveResponse. InstructionId: 4554,  Elapsed-Time: 0.85 seconds
# 37 - LLM-ChatCompletion. InstructionId: 4556,  Elapsed-Time: 2.14 seconds
# Palaven.SaveResponse. InstructionId: 4556,  Elapsed-Time: 0.82 seconds
# 38 - LLM-ChatCompletion. InstructionId: 4558,  Elapsed-Time: 4.68 seconds
# Palaven.SaveResponse. InstructionId: 4558,  Elapsed-Time: 0.85 seconds
# 39 - LLM-ChatCompletion. InstructionId: 4560,  Elapsed-Time: 2.74 seconds
# Palaven.SaveResponse. InstructionId: 4560,  Elapsed-Time: 0.84 seconds
# 40 - LLM-ChatCompletion. InstructionId: 4562,  Elapsed-Time: 2.12 seconds
# Palaven.SaveResponse. InstructionId: 4562,  Elapsed-Time: 0.85 seconds
# 41 - LLM-ChatCompletion. InstructionId: 4572,  Elapsed-Time: 5.69 seconds
# Palaven.SaveResponse. InstructionId: 4572,  Elapsed-Time: 0.82 seconds
# 42 - LLM-ChatCompletion. InstructionId: 4574,  Elapsed-Time: 3.59 seconds
# Palaven.SaveResponse. InstructionId: 4574,  Elapsed-Time: 0.86 seconds
# 43 - LLM-ChatCompletion. InstructionId: 4576,  Elapsed-Time: 1.86 seconds
# Palaven.SaveResponse. InstructionId: 4576,  Elapsed-Time: 0.83 seconds
# 44 - LLM-ChatCompletion. InstructionId: 4578,  Elapsed-Time: 2.06 seconds
# Palaven.SaveResponse. InstructionId: 4578,  Elapsed-Time: 0.83 seconds
# 45 - LLM-ChatCompletion. InstructionId: 4580,  Elapsed-Time: 2.49 seconds
# Palaven.SaveResponse. InstructionId: 4580,  Elapsed-Time: 0.84 seconds
# 46 - LLM-ChatCompletion. InstructionId: 4582,  Elapsed-Time: 2.65 seconds
# Palaven.SaveResponse. InstructionId: 4582,  Elapsed-Time: 0.84 seconds
# 47 - LLM-ChatCompletion. InstructionId: 4584,  Elapsed-Time: 2.78 seconds
# Palaven.SaveResponse. InstructionId: 4584,  Elapsed-Time: 0.90 seconds
# 48 - LLM-ChatCompletion. InstructionId: 4593,  Elapsed-Time: 4.83 seconds
# Palaven.SaveResponse. InstructionId: 4593,  Elapsed-Time: 0.83 seconds
# 49 - LLM-ChatCompletion. InstructionId: 4595,  Elapsed-Time: 4.29 seconds
# Palaven.SaveResponse. InstructionId: 4595,  Elapsed-Time: 0.84 seconds
# 50 - LLM-ChatCompletion. InstructionId: 4597,  Elapsed-Time: 2.20 seconds
# Palaven.SaveResponse. InstructionId: 4597,  Elapsed-Time: 0.86 seconds
# Start fetching batch 6
# Start fetching batch done...
# <ipython-input-8-9ad68d3380dc>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '¿Bajo qué condiciones se podrán deducir las construcciones, instalaciones o mejoras permanentes en activos fijos tangibles propiedad de terceros de acuerdo al Artículo 36 de la Ley del Impuesto Sobre la Renta del 2024?' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[instruction_id, 'instruction'] = instruction
# 1 - LLM-ChatCompletion. InstructionId: 4599,  Elapsed-Time: 2.43 seconds
# Palaven.SaveResponse. InstructionId: 4599,  Elapsed-Time: 0.86 seconds
# 2 - LLM-ChatCompletion. InstructionId: 4601,  Elapsed-Time: 4.25 seconds
# Palaven.SaveResponse. InstructionId: 4601,  Elapsed-Time: 0.83 seconds
# 3 - LLM-ChatCompletion. InstructionId: 4603,  Elapsed-Time: 2.34 seconds
# Palaven.SaveResponse. InstructionId: 4603,  Elapsed-Time: 0.87 seconds
# 4 - LLM-ChatCompletion. InstructionId: 4605,  Elapsed-Time: 5.31 seconds
# Palaven.SaveResponse. InstructionId: 4605,  Elapsed-Time: 0.83 seconds
# 5 - LLM-ChatCompletion. InstructionId: 4614,  Elapsed-Time: 4.52 seconds
# Palaven.SaveResponse. InstructionId: 4614,  Elapsed-Time: 0.83 seconds
# 6 - LLM-ChatCompletion. InstructionId: 4616,  Elapsed-Time: 4.52 seconds
# Palaven.SaveResponse. InstructionId: 4616,  Elapsed-Time: 0.85 seconds
# 7 - LLM-ChatCompletion. InstructionId: 4618,  Elapsed-Time: 3.85 seconds
# Palaven.SaveResponse. InstructionId: 4618,  Elapsed-Time: 0.83 seconds
# 8 - LLM-ChatCompletion. InstructionId: 4620,  Elapsed-Time: 2.20 seconds
# Palaven.SaveResponse. InstructionId: 4620,  Elapsed-Time: 0.85 seconds
# 9 - LLM-ChatCompletion. InstructionId: 4622,  Elapsed-Time: 2.07 seconds
# Palaven.SaveResponse. InstructionId: 4622,  Elapsed-Time: 0.85 seconds
# 10 - LLM-ChatCompletion. InstructionId: 4624,  Elapsed-Time: 3.77 seconds
# Palaven.SaveResponse. InstructionId: 4624,  Elapsed-Time: 0.85 seconds
# 11 - LLM-ChatCompletion. InstructionId: 4626,  Elapsed-Time: 2.29 seconds
# Palaven.SaveResponse. InstructionId: 4626,  Elapsed-Time: 0.86 seconds
# 12 - LLM-ChatCompletion. InstructionId: 4635,  Elapsed-Time: 9.25 seconds
# Palaven.SaveResponse. InstructionId: 4635,  Elapsed-Time: 0.84 seconds
# 13 - LLM-ChatCompletion. InstructionId: 4637,  Elapsed-Time: 3.08 seconds
# Palaven.SaveResponse. InstructionId: 4637,  Elapsed-Time: 0.85 seconds
# 14 - LLM-ChatCompletion. InstructionId: 4639,  Elapsed-Time: 6.06 seconds
# Palaven.SaveResponse. InstructionId: 4639,  Elapsed-Time: 0.84 seconds
# 15 - LLM-ChatCompletion. InstructionId: 4641,  Elapsed-Time: 2.63 seconds
# Palaven.SaveResponse. InstructionId: 4641,  Elapsed-Time: 0.85 seconds
# 16 - LLM-ChatCompletion. InstructionId: 4643,  Elapsed-Time: 4.24 seconds
# Palaven.SaveResponse. InstructionId: 4643,  Elapsed-Time: 0.84 seconds
# 17 - LLM-ChatCompletion. InstructionId: 4645,  Elapsed-Time: 5.18 seconds
# Palaven.SaveResponse. InstructionId: 4645,  Elapsed-Time: 0.86 seconds
# 18 - LLM-ChatCompletion. InstructionId: 4647,  Elapsed-Time: 2.57 seconds
# Palaven.SaveResponse. InstructionId: 4647,  Elapsed-Time: 0.86 seconds
# 19 - LLM-ChatCompletion. InstructionId: 4655,  Elapsed-Time: 4.55 seconds
# Palaven.SaveResponse. InstructionId: 4655,  Elapsed-Time: 0.83 seconds
# 20 - LLM-ChatCompletion. InstructionId: 4657,  Elapsed-Time: 3.63 seconds
# Palaven.SaveResponse. InstructionId: 4657,  Elapsed-Time: 0.85 seconds
# 21 - LLM-ChatCompletion. InstructionId: 4659,  Elapsed-Time: 2.15 seconds
# Palaven.SaveResponse. InstructionId: 4659,  Elapsed-Time: 0.83 seconds
# 22 - LLM-ChatCompletion. InstructionId: 4661,  Elapsed-Time: 3.38 seconds
# Palaven.SaveResponse. InstructionId: 4661,  Elapsed-Time: 0.83 seconds
# 23 - LLM-ChatCompletion. InstructionId: 4663,  Elapsed-Time: 4.33 seconds
# Palaven.SaveResponse. InstructionId: 4663,  Elapsed-Time: 0.83 seconds
# 24 - LLM-ChatCompletion. InstructionId: 4665,  Elapsed-Time: 2.11 seconds
# Palaven.SaveResponse. InstructionId: 4665,  Elapsed-Time: 0.83 seconds
# 25 - LLM-ChatCompletion. InstructionId: 4667,  Elapsed-Time: 4.00 seconds
# Palaven.SaveResponse. InstructionId: 4667,  Elapsed-Time: 0.83 seconds
# 26 - LLM-ChatCompletion. InstructionId: 4674,  Elapsed-Time: 4.35 seconds
# Palaven.SaveResponse. InstructionId: 4674,  Elapsed-Time: 0.85 seconds
# 27 - LLM-ChatCompletion. InstructionId: 4676,  Elapsed-Time: 1.81 seconds
# Palaven.SaveResponse. InstructionId: 4676,  Elapsed-Time: 0.84 seconds
# 28 - LLM-ChatCompletion. InstructionId: 4678,  Elapsed-Time: 4.06 seconds
# Palaven.SaveResponse. InstructionId: 4678,  Elapsed-Time: 0.85 seconds
# 29 - LLM-ChatCompletion. InstructionId: 4680,  Elapsed-Time: 3.37 seconds
# Palaven.SaveResponse. InstructionId: 4680,  Elapsed-Time: 0.85 seconds
# 30 - LLM-ChatCompletion. InstructionId: 4682,  Elapsed-Time: 4.15 seconds
# Palaven.SaveResponse. InstructionId: 4682,  Elapsed-Time: 0.84 seconds
# 31 - LLM-ChatCompletion. InstructionId: 4684,  Elapsed-Time: 4.05 seconds
# Palaven.SaveResponse. InstructionId: 4684,  Elapsed-Time: 0.85 seconds
# 32 - LLM-ChatCompletion. InstructionId: 4690,  Elapsed-Time: 2.84 seconds
# Palaven.SaveResponse. InstructionId: 4690,  Elapsed-Time: 0.84 seconds
# 33 - LLM-ChatCompletion. InstructionId: 4692,  Elapsed-Time: 2.20 seconds
# Palaven.SaveResponse. InstructionId: 4692,  Elapsed-Time: 0.82 seconds
# 34 - LLM-ChatCompletion. InstructionId: 4694,  Elapsed-Time: 2.71 seconds
# Palaven.SaveResponse. InstructionId: 4694,  Elapsed-Time: 0.84 seconds
# 35 - LLM-ChatCompletion. InstructionId: 4696,  Elapsed-Time: 3.76 seconds
# Palaven.SaveResponse. InstructionId: 4696,  Elapsed-Time: 0.84 seconds
# 36 - LLM-ChatCompletion. InstructionId: 4698,  Elapsed-Time: 5.54 seconds
# Palaven.SaveResponse. InstructionId: 4698,  Elapsed-Time: 0.85 seconds
# 37 - LLM-ChatCompletion. InstructionId: 4700,  Elapsed-Time: 1.64 seconds
# Palaven.SaveResponse. InstructionId: 4700,  Elapsed-Time: 0.85 seconds
# 38 - LLM-ChatCompletion. InstructionId: 4702,  Elapsed-Time: 5.34 seconds
# Palaven.SaveResponse. InstructionId: 4702,  Elapsed-Time: 0.83 seconds
# 39 - LLM-ChatCompletion. InstructionId: 4710,  Elapsed-Time: 6.19 seconds
# Palaven.SaveResponse. InstructionId: 4710,  Elapsed-Time: 0.86 seconds
# 40 - LLM-ChatCompletion. InstructionId: 4712,  Elapsed-Time: 2.91 seconds
# Palaven.SaveResponse. InstructionId: 4712,  Elapsed-Time: 0.83 seconds
# 41 - LLM-ChatCompletion. InstructionId: 4714,  Elapsed-Time: 5.65 seconds
# Palaven.SaveResponse. InstructionId: 4714,  Elapsed-Time: 0.84 seconds
# 42 - LLM-ChatCompletion. InstructionId: 4716,  Elapsed-Time: 2.61 seconds
# Palaven.SaveResponse. InstructionId: 4716,  Elapsed-Time: 0.82 seconds
# 43 - LLM-ChatCompletion. InstructionId: 4718,  Elapsed-Time: 2.59 seconds
# Palaven.SaveResponse. InstructionId: 4718,  Elapsed-Time: 0.85 seconds
# 44 - LLM-ChatCompletion. InstructionId: 4720,  Elapsed-Time: 3.06 seconds
# Palaven.SaveResponse. InstructionId: 4720,  Elapsed-Time: 0.82 seconds
# 45 - LLM-ChatCompletion. InstructionId: 4722,  Elapsed-Time: 1.70 seconds
# Palaven.SaveResponse. InstructionId: 4722,  Elapsed-Time: 0.82 seconds
# 46 - LLM-ChatCompletion. InstructionId: 4724,  Elapsed-Time: 2.09 seconds
# Palaven.SaveResponse. InstructionId: 4724,  Elapsed-Time: 0.88 seconds
# 47 - LLM-ChatCompletion. InstructionId: 4734,  Elapsed-Time: 5.20 seconds
# Palaven.SaveResponse. InstructionId: 4734,  Elapsed-Time: 0.85 seconds
# 48 - LLM-ChatCompletion. InstructionId: 4736,  Elapsed-Time: 1.45 seconds
# Palaven.SaveResponse. InstructionId: 4736,  Elapsed-Time: 0.85 seconds
# 49 - LLM-ChatCompletion. InstructionId: 4738,  Elapsed-Time: 3.25 seconds
# Palaven.SaveResponse. InstructionId: 4738,  Elapsed-Time: 0.86 seconds
# 50 - LLM-ChatCompletion. InstructionId: 4740,  Elapsed-Time: 2.40 seconds
# Palaven.SaveResponse. InstructionId: 4740,  Elapsed-Time: 0.83 seconds
# Start fetching batch 7
# Start fetching batch done...
# <ipython-input-8-9ad68d3380dc>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '¿Cómo deben ser valuados los bienes proporcionados por los contribuyentes en relación al artículo 43 de la Ley del Impuesto Sobre la Renta del 2024?' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[instruction_id, 'instruction'] = instruction
# 1 - LLM-ChatCompletion. InstructionId: 4742,  Elapsed-Time: 2.72 seconds
# Palaven.SaveResponse. InstructionId: 4742,  Elapsed-Time: 0.82 seconds
# 2 - LLM-ChatCompletion. InstructionId: 4747,  Elapsed-Time: 3.00 seconds
# Palaven.SaveResponse. InstructionId: 4747,  Elapsed-Time: 0.84 seconds
# 3 - LLM-ChatCompletion. InstructionId: 4749,  Elapsed-Time: 4.41 seconds
# Palaven.SaveResponse. InstructionId: 4749,  Elapsed-Time: 0.85 seconds
# 4 - LLM-ChatCompletion. InstructionId: 4751,  Elapsed-Time: 1.54 seconds
# Palaven.SaveResponse. InstructionId: 4751,  Elapsed-Time: 0.82 seconds
# 5 - LLM-ChatCompletion. InstructionId: 4753,  Elapsed-Time: 2.61 seconds
# Palaven.SaveResponse. InstructionId: 4753,  Elapsed-Time: 0.82 seconds
# 6 - LLM-ChatCompletion. InstructionId: 4755,  Elapsed-Time: 3.57 seconds
# Palaven.SaveResponse. InstructionId: 4755,  Elapsed-Time: 0.86 seconds
# 7 - LLM-ChatCompletion. InstructionId: 4757,  Elapsed-Time: 4.34 seconds
# ...
# 11 - LLM-ChatCompletion. InstructionId: 7461,  Elapsed-Time: 5.87 seconds
# Palaven.SaveResponse. InstructionId: 7461,  Elapsed-Time: 0.83 seconds
# 12 - LLM-ChatCompletion. InstructionId: 7463,  Elapsed-Time: 2.47 seconds
# Palaven.SaveResponse. InstructionId: 7463,  Elapsed-Time: 0.82 seconds
# 13 - LLM-ChatCompletion. InstructionId: 7465,  Elapsed-Time: 4.53 seconds
# Palaven.SaveResponse. InstructionId: 7465,  Elapsed-Time: 0.83 seconds
# 14 - LLM-ChatCompletion. InstructionId: 7474,  Elapsed-Time: 6.46 seconds
# Palaven.SaveResponse. InstructionId: 7474,  Elapsed-Time: 0.87 seconds
# 15 - LLM-ChatCompletion. InstructionId: 7476,  Elapsed-Time: 2.17 seconds
# Palaven.SaveResponse. InstructionId: 7476,  Elapsed-Time: 0.85 seconds
# 16 - LLM-ChatCompletion. InstructionId: 7478,  Elapsed-Time: 1.38 seconds
# Palaven.SaveResponse. InstructionId: 7478,  Elapsed-Time: 0.85 seconds
# 17 - LLM-ChatCompletion. InstructionId: 7480,  Elapsed-Time: 2.00 seconds
# Palaven.SaveResponse. InstructionId: 7480,  Elapsed-Time: 0.84 seconds
# 18 - LLM-ChatCompletion. InstructionId: 7482,  Elapsed-Time: 2.39 seconds
# Palaven.SaveResponse. InstructionId: 7482,  Elapsed-Time: 0.86 seconds
# 19 - LLM-ChatCompletion. InstructionId: 7484,  Elapsed-Time: 2.37 seconds
# Palaven.SaveResponse. InstructionId: 7484,  Elapsed-Time: 0.84 seconds
# 20 - LLM-ChatCompletion. InstructionId: 7490,  Elapsed-Time: 4.31 seconds
# Palaven.SaveResponse. InstructionId: 7490,  Elapsed-Time: 0.86 seconds
# 21 - LLM-ChatCompletion. InstructionId: 7492,  Elapsed-Time: 11.99 seconds
# Palaven.SaveResponse. InstructionId: 7492,  Elapsed-Time: 0.86 seconds
# 22 - LLM-ChatCompletion. InstructionId: 7494,  Elapsed-Time: 4.01 seconds
# Palaven.SaveResponse. InstructionId: 7494,  Elapsed-Time: 0.85 seconds
# 23 - LLM-ChatCompletion. InstructionId: 7496,  Elapsed-Time: 10.16 seconds
# Palaven.SaveResponse. InstructionId: 7496,  Elapsed-Time: 0.81 seconds
# 24 - LLM-ChatCompletion. InstructionId: 7498,  Elapsed-Time: 4.01 seconds
# Palaven.SaveResponse. InstructionId: 7498,  Elapsed-Time: 0.87 seconds
# 25 - LLM-ChatCompletion. InstructionId: 7500,  Elapsed-Time: 10.19 seconds
# Palaven.SaveResponse. InstructionId: 7500,  Elapsed-Time: 0.84 seconds
# 26 - LLM-ChatCompletion. InstructionId: 7502,  Elapsed-Time: 3.54 seconds
# Palaven.SaveResponse. InstructionId: 7502,  Elapsed-Time: 0.85 seconds
# 27 - LLM-ChatCompletion. InstructionId: 7510,  Elapsed-Time: 6.37 seconds
# Palaven.SaveResponse. InstructionId: 7510,  Elapsed-Time: 0.84 seconds
# 28 - LLM-ChatCompletion. InstructionId: 7512,  Elapsed-Time: 3.09 seconds
# Palaven.SaveResponse. InstructionId: 7512,  Elapsed-Time: 0.81 seconds
# 29 - LLM-ChatCompletion. InstructionId: 7514,  Elapsed-Time: 2.56 seconds
# Palaven.SaveResponse. InstructionId: 7514,  Elapsed-Time: 0.83 seconds
# 30 - LLM-ChatCompletion. InstructionId: 7516,  Elapsed-Time: 4.71 seconds
# Palaven.SaveResponse. InstructionId: 7516,  Elapsed-Time: 0.86 seconds
# 31 - LLM-ChatCompletion. InstructionId: 7518,  Elapsed-Time: 3.19 seconds
# Palaven.SaveResponse. InstructionId: 7518,  Elapsed-Time: 0.82 seconds
# 32 - LLM-ChatCompletion. InstructionId: 7520,  Elapsed-Time: 4.83 seconds
# Palaven.SaveResponse. InstructionId: 7520,  Elapsed-Time: 0.83 seconds
# 33 - LLM-ChatCompletion. InstructionId: 7522,  Elapsed-Time: 3.14 seconds
# Palaven.SaveResponse. InstructionId: 7522,  Elapsed-Time: 0.85 seconds
# 34 - LLM-ChatCompletion. InstructionId: 7524,  Elapsed-Time: 2.22 seconds
# Palaven.SaveResponse. InstructionId: 7524,  Elapsed-Time: 0.81 seconds
# 35 - LLM-ChatCompletion. InstructionId: 7526,  Elapsed-Time: 2.17 seconds
# Palaven.SaveResponse. InstructionId: 7526,  Elapsed-Time: 0.85 seconds
# 36 - LLM-ChatCompletion. InstructionId: 7535,  Elapsed-Time: 6.06 seconds
# Palaven.SaveResponse. InstructionId: 7535,  Elapsed-Time: 0.81 seconds
# 37 - LLM-ChatCompletion. InstructionId: 7537,  Elapsed-Time: 7.20 seconds
# Palaven.SaveResponse. InstructionId: 7537,  Elapsed-Time: 0.83 seconds
# 38 - LLM-ChatCompletion. InstructionId: 7539,  Elapsed-Time: 3.52 seconds
# Palaven.SaveResponse. InstructionId: 7539,  Elapsed-Time: 0.84 seconds
# 39 - LLM-ChatCompletion. InstructionId: 7541,  Elapsed-Time: 2.82 seconds
# Palaven.SaveResponse. InstructionId: 7541,  Elapsed-Time: 0.87 seconds
# 40 - LLM-ChatCompletion. InstructionId: 7543,  Elapsed-Time: 1.79 seconds
# Palaven.SaveResponse. InstructionId: 7543,  Elapsed-Time: 0.83 seconds
# 41 - LLM-ChatCompletion. InstructionId: 7545,  Elapsed-Time: 2.58 seconds
# Palaven.SaveResponse. InstructionId: 7545,  Elapsed-Time: 0.80 seconds
# 42 - LLM-ChatCompletion. InstructionId: 7547,  Elapsed-Time: 2.09 seconds
# Palaven.SaveResponse. InstructionId: 7547,  Elapsed-Time: 0.82 seconds
# 43 - LLM-ChatCompletion. InstructionId: 7549,  Elapsed-Time: 1.36 seconds
# Palaven.SaveResponse. InstructionId: 7549,  Elapsed-Time: 0.84 seconds
# 44 - LLM-ChatCompletion. InstructionId: 7557,  Elapsed-Time: 5.21 seconds
# Palaven.SaveResponse. InstructionId: 7557,  Elapsed-Time: 0.84 seconds
# 45 - LLM-ChatCompletion. InstructionId: 7559,  Elapsed-Time: 1.61 seconds
# Palaven.SaveResponse. InstructionId: 7559,  Elapsed-Time: 0.83 seconds
# 46 - LLM-ChatCompletion. InstructionId: 7561,  Elapsed-Time: 1.95 seconds
# Palaven.SaveResponse. InstructionId: 7561,  Elapsed-Time: 0.81 seconds
# 47 - LLM-ChatCompletion. InstructionId: 7563,  Elapsed-Time: 1.90 seconds
# Palaven.SaveResponse. InstructionId: 7563,  Elapsed-Time: 0.83 seconds
# 48 - LLM-ChatCompletion. InstructionId: 7565,  Elapsed-Time: 3.28 seconds
# Palaven.SaveResponse. InstructionId: 7565,  Elapsed-Time: 0.83 seconds
# 49 - LLM-ChatCompletion. InstructionId: 7567,  Elapsed-Time: 3.04 seconds
# Palaven.SaveResponse. InstructionId: 7567,  Elapsed-Time: 0.83 seconds
# 50 - LLM-ChatCompletion. InstructionId: 7569,  Elapsed-Time: 2.31 seconds
# Palaven.SaveResponse. InstructionId: 7569,  Elapsed-Time: 0.83 seconds
# Start fetching batch 27
# Start fetching batch done...
# <ipython-input-8-9ad68d3380dc>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Sumariza el artículo 169 de la Ley del Impuesto Sobre la Renta de 2024' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[instruction_id, 'instruction'] = instruction
# 1 - LLM-ChatCompletion. InstructionId: 7577,  Elapsed-Time: 6.55 seconds
# Palaven.SaveResponse. InstructionId: 7577,  Elapsed-Time: 0.86 seconds
# 2 - LLM-ChatCompletion. InstructionId: 7579,  Elapsed-Time: 2.88 seconds
# Palaven.SaveResponse. InstructionId: 7579,  Elapsed-Time: 0.81 seconds
# 3 - LLM-ChatCompletion. InstructionId: 7581,  Elapsed-Time: 4.69 seconds
# Palaven.SaveResponse. InstructionId: 7581,  Elapsed-Time: 0.81 seconds
# 4 - LLM-ChatCompletion. InstructionId: 7583,  Elapsed-Time: 1.71 seconds
# Palaven.SaveResponse. InstructionId: 7583,  Elapsed-Time: 0.83 seconds
# 5 - LLM-ChatCompletion. InstructionId: 7585,  Elapsed-Time: 2.05 seconds
# Palaven.SaveResponse. InstructionId: 7585,  Elapsed-Time: 0.84 seconds
# 6 - LLM-ChatCompletion. InstructionId: 7587,  Elapsed-Time: 2.30 seconds
# Palaven.SaveResponse. InstructionId: 7587,  Elapsed-Time: 0.83 seconds
# 7 - LLM-ChatCompletion. InstructionId: 7589,  Elapsed-Time: 2.20 seconds
# Palaven.SaveResponse. InstructionId: 7589,  Elapsed-Time: 0.85 seconds
# 8 - LLM-ChatCompletion. InstructionId: 7595,  Elapsed-Time: 3.17 seconds
# Palaven.SaveResponse. InstructionId: 7595,  Elapsed-Time: 0.85 seconds
# 9 - LLM-ChatCompletion. InstructionId: 7597,  Elapsed-Time: 2.57 seconds
# Palaven.SaveResponse. InstructionId: 7597,  Elapsed-Time: 0.81 seconds
# 10 - LLM-ChatCompletion. InstructionId: 7599,  Elapsed-Time: 3.30 seconds
# Palaven.SaveResponse. InstructionId: 7599,  Elapsed-Time: 0.87 seconds
# 11 - LLM-ChatCompletion. InstructionId: 7601,  Elapsed-Time: 3.09 seconds
# Palaven.SaveResponse. InstructionId: 7601,  Elapsed-Time: 0.82 seconds
# 12 - LLM-ChatCompletion. InstructionId: 7603,  Elapsed-Time: 3.42 seconds
# Palaven.SaveResponse. InstructionId: 7603,  Elapsed-Time: 0.84 seconds
# 13 - LLM-ChatCompletion. InstructionId: 7605,  Elapsed-Time: 3.37 seconds
# Palaven.SaveResponse. InstructionId: 7605,  Elapsed-Time: 0.84 seconds
# 14 - LLM-ChatCompletion. InstructionId: 7607,  Elapsed-Time: 1.96 seconds
# Palaven.SaveResponse. InstructionId: 7607,  Elapsed-Time: 0.80 seconds
# 15 - LLM-ChatCompletion. InstructionId: 7615,  Elapsed-Time: 7.16 seconds
# Palaven.SaveResponse. InstructionId: 7615,  Elapsed-Time: 0.84 seconds
# 16 - LLM-ChatCompletion. InstructionId: 7617,  Elapsed-Time: 5.34 seconds
# Palaven.SaveResponse. InstructionId: 7617,  Elapsed-Time: 0.85 seconds
# 17 - LLM-ChatCompletion. InstructionId: 7619,  Elapsed-Time: 2.53 seconds
# Palaven.SaveResponse. InstructionId: 7619,  Elapsed-Time: 0.82 seconds
# 18 - LLM-ChatCompletion. InstructionId: 7621,  Elapsed-Time: 3.32 seconds
# Palaven.SaveResponse. InstructionId: 7621,  Elapsed-Time: 0.84 seconds
# 19 - LLM-ChatCompletion. InstructionId: 7623,  Elapsed-Time: 2.09 seconds
# Palaven.SaveResponse. InstructionId: 7623,  Elapsed-Time: 0.81 seconds
# 20 - LLM-ChatCompletion. InstructionId: 7625,  Elapsed-Time: 3.66 seconds
# Palaven.SaveResponse. InstructionId: 7625,  Elapsed-Time: 0.84 seconds
# 21 - LLM-ChatCompletion. InstructionId: 7627,  Elapsed-Time: 2.86 seconds
# Palaven.SaveResponse. InstructionId: 7627,  Elapsed-Time: 0.84 seconds
# 22 - LLM-ChatCompletion. InstructionId: 7636,  Elapsed-Time: 7.37 seconds
# Palaven.SaveResponse. InstructionId: 7636,  Elapsed-Time: 0.85 seconds
# 23 - LLM-ChatCompletion. InstructionId: 7638,  Elapsed-Time: 3.07 seconds
# Palaven.SaveResponse. InstructionId: 7638,  Elapsed-Time: 0.85 seconds
# 24 - LLM-ChatCompletion. InstructionId: 7640,  Elapsed-Time: 1.79 seconds
# Palaven.SaveResponse. InstructionId: 7640,  Elapsed-Time: 0.84 seconds
# 25 - LLM-ChatCompletion. InstructionId: 7642,  Elapsed-Time: 2.86 seconds
# Palaven.SaveResponse. InstructionId: 7642,  Elapsed-Time: 0.83 seconds
# 26 - LLM-ChatCompletion. InstructionId: 7644,  Elapsed-Time: 2.45 seconds
# Palaven.SaveResponse. InstructionId: 7644,  Elapsed-Time: 0.85 seconds
# 27 - LLM-ChatCompletion. InstructionId: 7646,  Elapsed-Time: 2.38 seconds
# Palaven.SaveResponse. InstructionId: 7646,  Elapsed-Time: 0.83 seconds
# 28 - LLM-ChatCompletion. InstructionId: 7648,  Elapsed-Time: 1.11 seconds
# Palaven.SaveResponse. InstructionId: 7648,  Elapsed-Time: 0.84 seconds
# 29 - LLM-ChatCompletion. InstructionId: 7654,  Elapsed-Time: 4.88 seconds
# Palaven.SaveResponse. InstructionId: 7654,  Elapsed-Time: 0.82 seconds
# 30 - LLM-ChatCompletion. InstructionId: 7656,  Elapsed-Time: 3.56 seconds
# Palaven.SaveResponse. InstructionId: 7656,  Elapsed-Time: 0.81 seconds
# 31 - LLM-ChatCompletion. InstructionId: 7658,  Elapsed-Time: 2.76 seconds
# Palaven.SaveResponse. InstructionId: 7658,  Elapsed-Time: 0.82 seconds
# 32 - LLM-ChatCompletion. InstructionId: 7660,  Elapsed-Time: 4.74 seconds
# Palaven.SaveResponse. InstructionId: 7660,  Elapsed-Time: 0.81 seconds
# 33 - LLM-ChatCompletion. InstructionId: 7662,  Elapsed-Time: 3.33 seconds
# Palaven.SaveResponse. InstructionId: 7662,  Elapsed-Time: 0.84 seconds
# 34 - LLM-ChatCompletion. InstructionId: 7664,  Elapsed-Time: 2.93 seconds
# Palaven.SaveResponse. InstructionId: 7664,  Elapsed-Time: 0.82 seconds
# 35 - LLM-ChatCompletion. InstructionId: 7666,  Elapsed-Time: 3.10 seconds
# Palaven.SaveResponse. InstructionId: 7666,  Elapsed-Time: 0.83 seconds
# 36 - LLM-ChatCompletion. InstructionId: 7668,  Elapsed-Time: 4.88 seconds
# Palaven.SaveResponse. InstructionId: 7668,  Elapsed-Time: 0.83 seconds
# 37 - LLM-ChatCompletion. InstructionId: 7678,  Elapsed-Time: 7.48 seconds
# Palaven.SaveResponse. InstructionId: 7678,  Elapsed-Time: 0.84 seconds
# 38 - LLM-ChatCompletion. InstructionId: 7680,  Elapsed-Time: 3.36 seconds
# Palaven.SaveResponse. InstructionId: 7680,  Elapsed-Time: 0.83 seconds
# 39 - LLM-ChatCompletion. InstructionId: 7682,  Elapsed-Time: 2.06 seconds
# Palaven.SaveResponse. InstructionId: 7682,  Elapsed-Time: 0.83 seconds
# 40 - LLM-ChatCompletion. InstructionId: 7684,  Elapsed-Time: 2.69 seconds
# Palaven.SaveResponse. InstructionId: 7684,  Elapsed-Time: 0.87 seconds
# 41 - LLM-ChatCompletion. InstructionId: 7686,  Elapsed-Time: 2.42 seconds
# Palaven.SaveResponse. InstructionId: 7686,  Elapsed-Time: 0.83 seconds
# 42 - LLM-ChatCompletion. InstructionId: 7688,  Elapsed-Time: 2.68 seconds
# Palaven.SaveResponse. InstructionId: 7688,  Elapsed-Time: 0.85 seconds
# 43 - LLM-ChatCompletion. InstructionId: 7690,  Elapsed-Time: 1.78 seconds
# Palaven.SaveResponse. InstructionId: 7690,  Elapsed-Time: 0.83 seconds
# 44 - LLM-ChatCompletion. InstructionId: 7692,  Elapsed-Time: 2.54 seconds
# Palaven.SaveResponse. InstructionId: 7692,  Elapsed-Time: 0.84 seconds
# 45 - LLM-ChatCompletion. InstructionId: 7700,  Elapsed-Time: 4.45 seconds
# Palaven.SaveResponse. InstructionId: 7700,  Elapsed-Time: 0.82 seconds
# 46 - LLM-ChatCompletion. InstructionId: 7702,  Elapsed-Time: 8.93 seconds
# Palaven.SaveResponse. InstructionId: 7702,  Elapsed-Time: 1.02 seconds
# 47 - LLM-ChatCompletion. InstructionId: 7704,  Elapsed-Time: 6.90 seconds
# Palaven.SaveResponse. InstructionId: 7704,  Elapsed-Time: 1.01 seconds
# 48 - LLM-ChatCompletion. InstructionId: 7706,  Elapsed-Time: 9.91 seconds
# Palaven.SaveResponse. InstructionId: 7706,  Elapsed-Time: 1.04 seconds
# 49 - LLM-ChatCompletion. InstructionId: 7708,  Elapsed-Time: 7.81 seconds
# Palaven.SaveResponse. InstructionId: 7708,  Elapsed-Time: 1.04 seconds
# 50 - LLM-ChatCompletion. InstructionId: 7710,  Elapsed-Time: 7.22 seconds
# Palaven.SaveResponse. InstructionId: 7710,  Elapsed-Time: 1.02 seconds
# Start fetching batch 28
# Start fetching batch done...
# <ipython-input-8-9ad68d3380dc>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '¿Los residentes en México y los residentes en el extranjero con establecimiento permanente en el país están obligados a pagar impuestos por los ingresos sujetos a regímenes fiscales preferentes obtenidos a través de entidades extranjeras en las que participen?' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[instruction_id, 'instruction'] = instruction
# 1 - LLM-ChatCompletion. InstructionId: 7712,  Elapsed-Time: 6.82 seconds
# Palaven.SaveResponse. InstructionId: 7712,  Elapsed-Time: 1.03 seconds
# 2 - LLM-ChatCompletion. InstructionId: 7714,  Elapsed-Time: 5.81 seconds
# Palaven.SaveResponse. InstructionId: 7714,  Elapsed-Time: 1.00 seconds
# 3 - LLM-ChatCompletion. InstructionId: 7716,  Elapsed-Time: 9.97 seconds
# Palaven.SaveResponse. InstructionId: 7716,  Elapsed-Time: 1.03 seconds
# 4 - LLM-ChatCompletion. InstructionId: 7725,  Elapsed-Time: 13.97 seconds
# Palaven.SaveResponse. InstructionId: 7725,  Elapsed-Time: 1.03 seconds
# 5 - LLM-ChatCompletion. InstructionId: 7727,  Elapsed-Time: 5.84 seconds
# Palaven.SaveResponse. InstructionId: 7727,  Elapsed-Time: 1.03 seconds
# 6 - LLM-ChatCompletion. InstructionId: 7729,  Elapsed-Time: 4.99 seconds
# Palaven.SaveResponse. InstructionId: 7729,  Elapsed-Time: 1.05 seconds
# 7 - LLM-ChatCompletion. InstructionId: 7731,  Elapsed-Time: 5.64 seconds
# Palaven.SaveResponse. InstructionId: 7731,  Elapsed-Time: 1.00 seconds
# 8 - LLM-ChatCompletion. InstructionId: 7733,  Elapsed-Time: 5.29 seconds
# Palaven.SaveResponse. InstructionId: 7733,  Elapsed-Time: 1.01 seconds
# 9 - LLM-ChatCompletion. InstructionId: 7735,  Elapsed-Time: 5.74 seconds
# Palaven.SaveResponse. InstructionId: 7735,  Elapsed-Time: 1.00 seconds
# 10 - LLM-ChatCompletion. InstructionId: 7737,  Elapsed-Time: 4.07 seconds
# Palaven.SaveResponse. InstructionId: 7737,  Elapsed-Time: 1.01 seconds
# 11 - LLM-ChatCompletion. InstructionId: 7739,  Elapsed-Time: 4.23 seconds
# Palaven.SaveResponse. InstructionId: 7739,  Elapsed-Time: 1.01 seconds
# 12 - LLM-ChatCompletion. InstructionId: 7741,  Elapsed-Time: 5.62 seconds
# Palaven.SaveResponse. InstructionId: 7741,  Elapsed-Time: 1.00 seconds
# 13 - LLM-ChatCompletion. InstructionId: 7751,  Elapsed-Time: 10.13 seconds
# Palaven.SaveResponse. InstructionId: 7751,  Elapsed-Time: 1.04 seconds

# %% [markdown]
# ### 4. Evaluation metrics

# %% [markdown]
# ### 4.1. BERTScore

# %%
import pandas as pd

def build_responses_df():
  dataframe = pd.DataFrame(columns=['instruction_id',
    'evaluation_session_id', 'dataset_id', 'batch_size', 'large_language_model',
    'device_info', 'excercise_type', 'batch_number', 'instruction',
    'response', 'category', 'response_to_evaluate', 'elapsed_time'])

  dataframe['evaluation_session_id'] = dataframe['evaluation_session_id'].astype('object')
  dataframe['dataset_id'] = dataframe['dataset_id'].astype('object')
  dataframe['large_language_model'] = dataframe['large_language_model'].astype('object')
  dataframe['device_info'] = dataframe['device_info'].astype('object')
  dataframe['excercise_type'] = dataframe['excercise_type'].astype('object')
  dataframe['instruction'] = dataframe['instruction'].astype('object')
  dataframe['response'] = dataframe['response'].astype('object')
  dataframe['category'] = dataframe['category'].astype('object')
  dataframe['response_to_evaluate'] = dataframe['response_to_evaluate'].astype('object')

  dataframe.set_index('instruction_id', inplace=True)

  return dataframe


def add_response_to_df(dataframe, response):
  dataframe.loc[response['instructionId'], 'evaluation_session_id'] = response['evaluationSessionId']
  dataframe.loc[response['instructionId'], 'dataset_id'] = response['datasetId']
  dataframe.loc[response['instructionId'], 'batch_size'] = response['batchSize']
  dataframe.loc[response['instructionId'], 'large_language_model'] = response['largeLanguageModel']
  dataframe.loc[response['instructionId'], 'device_info'] = response['deviceInfo']
  dataframe.loc[response['instructionId'], 'excercise_type'] = response['evaluationExercise']
  dataframe.loc[response['instructionId'], 'batch_number'] = response['batchNumber']
  dataframe.loc[response['instructionId'], 'instruction'] = response['instruction']
  dataframe.loc[response['instructionId'], 'response'] = response['response']
  dataframe.loc[response['instructionId'], 'category'] = response['category']
  dataframe.loc[response['instructionId'], 'response_to_evaluate'] = response['llmResponseToEvaluate']
  dataframe.loc[response['instructionId'], 'elapsed_time'] = response['elapsedTime']

# %%
# !pip install bert_score
# Out:
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.4.0+cu121)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.1.4)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.42.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert_score) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.66.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert_score) (3.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert_score) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2024.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (2024.6.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.23.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.19.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (3.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert_score) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert_score) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0.0->bert_score) (1.3.0)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 971.4 kB/s eta 0:00:00
# Installing collected packages: bert_score
# Successfully installed bert_score-0.3.13

# %%
from bert_score import score as bert_score

for batch_number in range(1, 29):

  model_responses_df = build_responses_df()

  print(f'Palaven. Bertscore evaluation. Start processing batch: {batch_number}')

  model_responses = palaven_api.fetch_model_responses(evaluation_session_id, 'llmfinetunedrag', batch_number)

  for item in model_responses:
    add_response_to_df(model_responses_df, item)

  references = model_responses_df['response'].tolist()
  candidates = model_responses_df['response_to_evaluate'].tolist()

  accuracy, recall, f1 = bert_score(candidates, references, lang='es', verbose=True, device='cuda')

  accuracy = accuracy.tolist()
  recall = recall.tolist()
  f1 = f1.tolist()

  average_accuracy = sum(accuracy) / len(accuracy)
  average_recall = sum(recall) / len(recall)
  average_f1 = sum(f1) / len(f1)

  print(f'Palaven. Bertscore evaluation. Batch: {batch_number}. Average accuracy: {average_accuracy}. Average recall: {average_recall}. Average F1: {average_f1}')

  palaven_api.save_bert_score_metrics(evaluation_session_id, 'llmfinetunedrag', batch_number, average_accuracy, average_recall, average_f1)

  print(f'Palaven. Bertscore evaluation. Posted batch {batch_number}')
# Out:
# Palaven. Bertscore evaluation. Start processing batch: 1
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 1.86 seconds, 26.88 sentences/sec
# Palaven. Bertscore evaluation. Batch: 1. Average accuracy: 0.7768898093700409. Average recall: 0.8239548087120057. Average F1: 0.7985292959213257
# Palaven. Bertscore evaluation. Posted batch 1
# Palaven. Bertscore evaluation. Start processing batch: 2
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.41 seconds, 122.62 sentences/sec
# Palaven. Bertscore evaluation. Batch: 2. Average accuracy: 0.8091520690917968. Average recall: 0.853687915802002. Average F1: 0.8294715702533721
# Palaven. Bertscore evaluation. Posted batch 2
# Palaven. Bertscore evaluation. Start processing batch: 3
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.37 seconds, 135.57 sentences/sec
# Palaven. Bertscore evaluation. Batch: 3. Average accuracy: 0.8124841642379761. Average recall: 0.8745517694950103. Average F1: 0.841670058965683
# Palaven. Bertscore evaluation. Posted batch 3
# Palaven. Bertscore evaluation. Start processing batch: 4
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.35 seconds, 144.29 sentences/sec
# Palaven. Bertscore evaluation. Batch: 4. Average accuracy: 0.7818746638298034. Average recall: 0.8384707593917846. Average F1: 0.808023065328598
# Palaven. Bertscore evaluation. Posted batch 4
# Palaven. Bertscore evaluation. Start processing batch: 5
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.34 seconds, 145.03 sentences/sec
# Palaven. Bertscore evaluation. Batch: 5. Average accuracy: 0.7883153593540192. Average recall: 0.8561285436153412. Average F1: 0.8185349249839783
# Palaven. Bertscore evaluation. Posted batch 5
# Palaven. Bertscore evaluation. Start processing batch: 6
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.38 seconds, 133.14 sentences/sec
# Palaven. Bertscore evaluation. Batch: 6. Average accuracy: 0.7909358322620392. Average recall: 0.8534179246425628. Average F1: 0.8196783459186554
# Palaven. Bertscore evaluation. Posted batch 6
# Palaven. Bertscore evaluation. Start processing batch: 7
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.30 seconds, 166.66 sentences/sec
# Palaven. Bertscore evaluation. Batch: 7. Average accuracy: 0.8114375966787338. Average recall: 0.8513154220581055. Average F1: 0.8294675433635712
# Palaven. Bertscore evaluation. Posted batch 7
# Palaven. Bertscore evaluation. Start processing batch: 8
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.38 seconds, 130.34 sentences/sec
# Palaven. Bertscore evaluation. Batch: 8. Average accuracy: 0.751822692155838. Average recall: 0.8429088032245636. Average F1: 0.7922339940071106
# Palaven. Bertscore evaluation. Posted batch 8
# Palaven. Bertscore evaluation. Start processing batch: 9
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.38 seconds, 131.70 sentences/sec
# Palaven. Bertscore evaluation. Batch: 9. Average accuracy: 0.789048952460289. Average recall: 0.8402072417736054. Average F1: 0.8121535766124726
# Palaven. Bertscore evaluation. Posted batch 9
# Palaven. Bertscore evaluation. Start processing batch: 10
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.30 seconds, 164.40 sentences/sec
# Palaven. Bertscore evaluation. Batch: 10. Average accuracy: 0.8093414163589477. Average recall: 0.8693436181545258. Average F1: 0.8369498729705811
# Palaven. Bertscore evaluation. Posted batch 10
# Palaven. Bertscore evaluation. Start processing batch: 11
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.44 seconds, 114.90 sentences/sec
# Palaven. Bertscore evaluation. Batch: 11. Average accuracy: 0.7651406121253967. Average recall: 0.8404307353496552. Average F1: 0.7992176496982575
# Palaven. Bertscore evaluation. Posted batch 11
# Palaven. Bertscore evaluation. Start processing batch: 12
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.35 seconds, 142.48 sentences/sec
# Palaven. Bertscore evaluation. Batch: 12. Average accuracy: 0.7593128764629364. Average recall: 0.8144321167469024. Average F1: 0.7846625208854675
# Palaven. Bertscore evaluation. Posted batch 12
# Palaven. Bertscore evaluation. Start processing batch: 13
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.31 seconds, 158.93 sentences/sec
# Palaven. Bertscore evaluation. Batch: 13. Average accuracy: 0.7964415681362152. Average recall: 0.8561017286777496. Average F1: 0.8239699256420135
# Palaven. Bertscore evaluation. Posted batch 13
# Palaven. Bertscore evaluation. Start processing batch: 14
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.35 seconds, 141.88 sentences/sec
# Palaven. Bertscore evaluation. Batch: 14. Average accuracy: 0.7836673212051392. Average recall: 0.8477241110801697. Average F1: 0.8129758477210999
# Palaven. Bertscore evaluation. Posted batch 14
# Palaven. Bertscore evaluation. Start processing batch: 15
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.37 seconds, 133.68 sentences/sec
# Palaven. Bertscore evaluation. Batch: 15. Average accuracy: 0.7746006369590759. Average recall: 0.8374599599838257. Average F1: 0.8037290370464325
# Palaven. Bertscore evaluation. Posted batch 15
# Palaven. Bertscore evaluation. Start processing batch: 16
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.53 seconds, 94.48 sentences/sec
# Palaven. Bertscore evaluation. Batch: 16. Average accuracy: 0.8068077826499939. Average recall: 0.8565284764766693. Average F1: 0.8294456124305725
# Palaven. Bertscore evaluation. Posted batch 16
# Palaven. Bertscore evaluation. Start processing batch: 17
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.38 seconds, 131.84 sentences/sec
# Palaven. Bertscore evaluation. Batch: 17. Average accuracy: 0.779716876745224. Average recall: 0.8451159369945526. Average F1: 0.809598296880722
# Palaven. Bertscore evaluation. Posted batch 17
# Palaven. Bertscore evaluation. Start processing batch: 18
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.31 seconds, 161.48 sentences/sec
# Palaven. Bertscore evaluation. Batch: 18. Average accuracy: 0.7685696053504943. Average recall: 0.8544165790081024. Average F1: 0.8076218068599701
# Palaven. Bertscore evaluation. Posted batch 18
# Palaven. Bertscore evaluation. Start processing batch: 19
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.34 seconds, 145.78 sentences/sec
# Palaven. Bertscore evaluation. Batch: 19. Average accuracy: 0.8117935526371002. Average recall: 0.8642223286628723. Average F1: 0.8358750569820405
# Palaven. Bertscore evaluation. Posted batch 19
# Palaven. Bertscore evaluation. Start processing batch: 20
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.39 seconds, 128.92 sentences/sec
# Palaven. Bertscore evaluation. Batch: 20. Average accuracy: 0.7789082849025726. Average recall: 0.8514928841590881. Average F1: 0.8120854365825653
# Palaven. Bertscore evaluation. Posted batch 20
# Palaven. Bertscore evaluation. Start processing batch: 21
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.29 seconds, 173.19 sentences/sec
# Palaven. Bertscore evaluation. Batch: 21. Average accuracy: 0.7871268010139465. Average recall: 0.8600447297096252. Average F1: 0.8200163924694062
# Palaven. Bertscore evaluation. Posted batch 21
# Palaven. Bertscore evaluation. Start processing batch: 22
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.31 seconds, 159.70 sentences/sec
# Palaven. Bertscore evaluation. Batch: 22. Average accuracy: 0.7783311396837235. Average recall: 0.8424203979969025. Average F1: 0.8071143651008605
# Palaven. Bertscore evaluation. Posted batch 22
# Palaven. Bertscore evaluation. Start processing batch: 23
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.34 seconds, 146.51 sentences/sec
# Palaven. Bertscore evaluation. Batch: 23. Average accuracy: 0.7882441699504852. Average recall: 0.8444539344310761. Average F1: 0.8139873027801514
# Palaven. Bertscore evaluation. Posted batch 23
# Palaven. Bertscore evaluation. Start processing batch: 24
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.35 seconds, 142.96 sentences/sec
# Palaven. Bertscore evaluation. Batch: 24. Average accuracy: 0.7823008286952973. Average recall: 0.8460995721817016. Average F1: 0.8110202252864838
# Palaven. Bertscore evaluation. Posted batch 24
# Palaven. Bertscore evaluation. Start processing batch: 25
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.41 seconds, 122.38 sentences/sec
# Palaven. Bertscore evaluation. Batch: 25. Average accuracy: 0.7801258540153504. Average recall: 0.8667853105068207. Average F1: 0.8195833671092987
# Palaven. Bertscore evaluation. Posted batch 25
# Palaven. Bertscore evaluation. Start processing batch: 26
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.40 seconds, 124.32 sentences/sec
# Palaven. Bertscore evaluation. Batch: 26. Average accuracy: 0.7382201063632965. Average recall: 0.8417977285385132. Average F1: 0.7851281726360321
# Palaven. Bertscore evaluation. Posted batch 26
# Palaven. Bertscore evaluation. Start processing batch: 27
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.32 seconds, 154.23 sentences/sec
# Palaven. Bertscore evaluation. Batch: 27. Average accuracy: 0.7797505235671998. Average recall: 0.8492556488513947. Average F1: 0.8118519186973572
# Palaven. Bertscore evaluation. Posted batch 27
# Palaven. Bertscore evaluation. Start processing batch: 28
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.14 seconds, 94.37 sentences/sec
# Palaven. Bertscore evaluation. Batch: 28. Average accuracy: 0.8292911419501672. Average recall: 0.8591858698771551. Average F1: 0.8433318229822012
# Palaven. Bertscore evaluation. Posted batch 28

# %% [markdown]
# ### 4.2. ROUGE Score (1,2,L)

# %%
# !pip install rouge_score
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.66.5)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=4de28694102b6e60c344b58fd7cad33157a10c00bc5d5dd7f690677c65177fcd
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2

# %%
from rouge_score import rouge_scorer

for batch_number in range(1, 29):

  model_responses_df = build_responses_df()

  print(f'Palaven. ROUGE evaluation. Start processing batch: {batch_number}')
  model_responses = palaven_api.fetch_model_responses(evaluation_session_id, 'llmfinetunedrag', batch_number)

  for item in model_responses:
    add_response_to_df(model_responses_df, item)

  scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)

  r1_precision, r1_recall, r1_f1 = [], [], []
  r2_precision, r2_recall, r2_f1 = [], [], []
  rL_precision, rL_recall, rL_f1 = [], [], []

  for _, row in model_responses_df.iterrows():
    reference = row['response']
    candidate = row['response_to_evaluate']

    scores = scorer.score(reference, candidate)

    #ROUGE-1
    r1_precision.append(scores['rouge1'].precision)
    r1_recall.append(scores['rouge1'].recall)
    r1_f1.append(scores['rouge1'].fmeasure)

    #ROUGE-2
    r2_precision.append(scores['rouge2'].precision)
    r2_recall.append(scores['rouge2'].recall)
    r2_f1.append(scores['rouge2'].fmeasure)

    #ROUGE-L
    rL_precision.append(scores['rougeL'].precision)
    rL_recall.append(scores['rougeL'].recall)
    rL_f1.append(scores['rougeL'].fmeasure)


  average_r1_precision = sum(r1_precision) / len(r1_precision)
  average_r1_recall = sum(r1_recall) / len(r1_recall)
  average_r1_f1 = sum(r1_f1) / len(r1_f1)

  average_r2_precision = sum(r2_precision) / len(r2_precision)
  average_r2_recall = sum(r2_recall) / len(r2_recall)
  average_r2_f1 = sum(r2_f1) / len(r2_f1)

  average_rL_precision = sum(rL_precision) / len(rL_precision)
  average_rL_recall = sum(rL_recall) / len(rL_recall)
  average_rL_f1 = sum(rL_f1) / len(rL_f1)

  rouge_metrics = []

  rouge_metrics.append({
      'rougeScoreType': 'rouge1',
      'batchNumber': batch_number,
      'precision': average_r1_precision,
      'recall': average_r1_recall,
      'f1': average_r1_f1
  });

  rouge_metrics.append({
      'rougeScoreType': 'rouge2',
      'batchNumber': batch_number,
      'precision': average_r2_precision,
      'recall': average_r2_recall,
      'f1': average_r2_f1
  });

  rouge_metrics.append({
      'rougeScoreType': 'rougeL',
      'batchNumber': batch_number,
      'precision': average_rL_precision,
      'recall': average_rL_recall,
      'f1': average_rL_f1
  });

  print(rouge_metrics)

  print(f'Palaven. ROUGE evaluation finished for batch: {batch_number}.')

  palaven_api.save_rouge_metrics(evaluation_session_id, 'llmfinetunedrag', batch_number, rouge_metrics)

  print(f'Palaven. Bertscore evaluation. Posted batch {batch_number}')
# Out:
# Palaven. ROUGE evaluation. Start processing batch: 1
# [{'rougeScoreType': 'rouge1', 'batchNumber': 1, 'precision': 0.4684774919888217, 'recall': 0.6915906500512645, 'f1': 0.5181180072162592}, {'rougeScoreType': 'rouge2', 'batchNumber': 1, 'precision': 0.3421192096073171, 'recall': 0.48039003556497856, 'f1': 0.3800218640674516}, {'rougeScoreType': 'rougeL', 'batchNumber': 1, 'precision': 0.4174152728463804, 'recall': 0.6189775816800154, 'f1': 0.4618079036245441}]
# Palaven. ROUGE evaluation finished for batch: 1.
# Palaven. Bertscore evaluation. Posted batch 1
# Palaven. ROUGE evaluation. Start processing batch: 2
# [{'rougeScoreType': 'rouge1', 'batchNumber': 2, 'precision': 0.5474899788572336, 'recall': 0.761734852104298, 'f1': 0.5966189044350994}, {'rougeScoreType': 'rouge2', 'batchNumber': 2, 'precision': 0.44459671123971306, 'recall': 0.6249191274917981, 'f1': 0.49097433411934666}, {'rougeScoreType': 'rougeL', 'batchNumber': 2, 'precision': 0.4938824784527797, 'recall': 0.6857895974558985, 'f1': 0.5399704170368294}]
# Palaven. ROUGE evaluation finished for batch: 2.
# Palaven. Bertscore evaluation. Posted batch 2
# Palaven. ROUGE evaluation. Start processing batch: 3
# [{'rougeScoreType': 'rouge1', 'batchNumber': 3, 'precision': 0.5416191499610075, 'recall': 0.81230252180715, 'f1': 0.6253815111341993}, {'rougeScoreType': 'rouge2', 'batchNumber': 3, 'precision': 0.4286452335625078, 'recall': 0.6613968230556138, 'f1': 0.5014152167499247}, {'rougeScoreType': 'rougeL', 'batchNumber': 3, 'precision': 0.49249023695907596, 'recall': 0.7476256082844176, 'f1': 0.5719785740464075}]
# Palaven. ROUGE evaluation finished for batch: 3.
# Palaven. Bertscore evaluation. Posted batch 3
# Palaven. ROUGE evaluation. Start processing batch: 4
# [{'rougeScoreType': 'rouge1', 'batchNumber': 4, 'precision': 0.4867716704328323, 'recall': 0.7289982033085104, 'f1': 0.5473711896512116}, {'rougeScoreType': 'rouge2', 'batchNumber': 4, 'precision': 0.37431654810522597, 'recall': 0.5579535381606382, 'f1': 0.4238632303410679}, {'rougeScoreType': 'rougeL', 'batchNumber': 4, 'precision': 0.42864570303729843, 'recall': 0.645733517969604, 'f1': 0.48453341282050066}]
# Palaven. ROUGE evaluation finished for batch: 4.
# Palaven. Bertscore evaluation. Posted batch 4
# Palaven. ROUGE evaluation. Start processing batch: 5
# [{'rougeScoreType': 'rouge1', 'batchNumber': 5, 'precision': 0.49517463217257, 'recall': 0.8104114268267355, 'f1': 0.5445820885685158}, {'rougeScoreType': 'rouge2', 'batchNumber': 5, 'precision': 0.3975282870264094, 'recall': 0.5722870704113209, 'f1': 0.4352322492904767}, {'rougeScoreType': 'rougeL', 'batchNumber': 5, 'precision': 0.4484176595541747, 'recall': 0.7467833741695948, 'f1': 0.49420276743394714}]
# Palaven. ROUGE evaluation finished for batch: 5.
# Palaven. Bertscore evaluation. Posted batch 5
# Palaven. ROUGE evaluation. Start processing batch: 6
# [{'rougeScoreType': 'rouge1', 'batchNumber': 6, 'precision': 0.4751750486430514, 'recall': 0.7712623384769463, 'f1': 0.5536283421889806}, {'rougeScoreType': 'rouge2', 'batchNumber': 6, 'precision': 0.3730569327010392, 'recall': 0.6027973399701405, 'f1': 0.43376222288880734}, {'rougeScoreType': 'rougeL', 'batchNumber': 6, 'precision': 0.420120719400767, 'recall': 0.6779520506733836, 'f1': 0.4886244667741768}]
# Palaven. ROUGE evaluation finished for batch: 6.
# Palaven. Bertscore evaluation. Posted batch 6
# Palaven. ROUGE evaluation. Start processing batch: 7
# [{'rougeScoreType': 'rouge1', 'batchNumber': 7, 'precision': 0.5510510818164223, 'recall': 0.7664798649055465, 'f1': 0.5996442376811054}, {'rougeScoreType': 'rouge2', 'batchNumber': 7, 'precision': 0.4419412511976551, 'recall': 0.5981368591730862, 'f1': 0.47793748633873806}, {'rougeScoreType': 'rougeL', 'batchNumber': 7, 'precision': 0.5048123001572243, 'recall': 0.6993632581703912, 'f1': 0.5470450263086043}]
# Palaven. ROUGE evaluation finished for batch: 7.
# Palaven. Bertscore evaluation. Posted batch 7
# Palaven. ROUGE evaluation. Start processing batch: 8
# [{'rougeScoreType': 'rouge1', 'batchNumber': 8, 'precision': 0.40436614871820054, 'recall': 0.7850410112188727, 'f1': 0.4770767900981662}, {'rougeScoreType': 'rouge2', 'batchNumber': 8, 'precision': 0.3165563760329644, 'recall': 0.6129270985117433, 'f1': 0.37191383381412935}, {'rougeScoreType': 'rougeL', 'batchNumber': 8, 'precision': 0.36015296876355235, 'recall': 0.7065690778887427, 'f1': 0.4265342684828218}]
# Palaven. ROUGE evaluation finished for batch: 8.
# Palaven. Bertscore evaluation. Posted batch 8
# Palaven. ROUGE evaluation. Start processing batch: 9
# [{'rougeScoreType': 'rouge1', 'batchNumber': 9, 'precision': 0.5130823224537406, 'recall': 0.7621614697356519, 'f1': 0.5696975353786039}, {'rougeScoreType': 'rouge2', 'batchNumber': 9, 'precision': 0.4000002318429663, 'recall': 0.5815407220723654, 'f1': 0.4426356276216904}, {'rougeScoreType': 'rougeL', 'batchNumber': 9, 'precision': 0.4502125223651502, 'recall': 0.6743294768368787, 'f1': 0.4997394659841538}]
# Palaven. ROUGE evaluation finished for batch: 9.
# Palaven. Bertscore evaluation. Posted batch 9
# Palaven. ROUGE evaluation. Start processing batch: 10
# [{'rougeScoreType': 'rouge1', 'batchNumber': 10, 'precision': 0.5483279922121072, 'recall': 0.8045975494432352, 'f1': 0.6228291441626354}, {'rougeScoreType': 'rouge2', 'batchNumber': 10, 'precision': 0.4560173937500963, 'recall': 0.6796239763911939, 'f1': 0.5203597369776739}, {'rougeScoreType': 'rougeL', 'batchNumber': 10, 'precision': 0.5031829823253785, 'recall': 0.7394396918724783, 'f1': 0.5717260248394352}]
# Palaven. ROUGE evaluation finished for batch: 10.
# Palaven. Bertscore evaluation. Posted batch 10
# Palaven. ROUGE evaluation. Start processing batch: 11
# [{'rougeScoreType': 'rouge1', 'batchNumber': 11, 'precision': 0.4435344985526299, 'recall': 0.744022540195333, 'f1': 0.5167579392586807}, {'rougeScoreType': 'rouge2', 'batchNumber': 11, 'precision': 0.327273624326595, 'recall': 0.5690004600092701, 'f1': 0.3858183472888303}, {'rougeScoreType': 'rougeL', 'batchNumber': 11, 'precision': 0.389990400518261, 'recall': 0.6563416499994035, 'f1': 0.4545917073960506}]
# Palaven. ROUGE evaluation finished for batch: 11.
# Palaven. Bertscore evaluation. Posted batch 11
# Palaven. ROUGE evaluation. Start processing batch: 12
# [{'rougeScoreType': 'rouge1', 'batchNumber': 12, 'precision': 0.4194326424440378, 'recall': 0.6567901453499462, 'f1': 0.47648158256512746}, {'rougeScoreType': 'rouge2', 'batchNumber': 12, 'precision': 0.29942230854021246, 'recall': 0.45805243974038584, 'f1': 0.34405680766812435}, {'rougeScoreType': 'rougeL', 'batchNumber': 12, 'precision': 0.3643336267866068, 'recall': 0.5777327921992786, 'f1': 0.41595024530890307}]
# Palaven. ROUGE evaluation finished for batch: 12.
# Palaven. Bertscore evaluation. Posted batch 12
# Palaven. ROUGE evaluation. Start processing batch: 13
# [{'rougeScoreType': 'rouge1', 'batchNumber': 13, 'precision': 0.5110385279622848, 'recall': 0.7667068831966192, 'f1': 0.5900043420745235}, {'rougeScoreType': 'rouge2', 'batchNumber': 13, 'precision': 0.39656521016784635, 'recall': 0.5995689614250318, 'f1': 0.46003576255059575}, {'rougeScoreType': 'rougeL', 'batchNumber': 13, 'precision': 0.4428341815168145, 'recall': 0.6651978545740098, 'f1': 0.5116369923830659}]
# Palaven. ROUGE evaluation finished for batch: 13.
# Palaven. Bertscore evaluation. Posted batch 13
# Palaven. ROUGE evaluation. Start processing batch: 14
# [{'rougeScoreType': 'rouge1', 'batchNumber': 14, 'precision': 0.48352045038929964, 'recall': 0.7720968818526996, 'f1': 0.5581115720470817}, {'rougeScoreType': 'rouge2', 'batchNumber': 14, 'precision': 0.36042841405559706, 'recall': 0.5925455855967321, 'f1': 0.4198459538373107}, {'rougeScoreType': 'rougeL', 'batchNumber': 14, 'precision': 0.4241554272074148, 'recall': 0.6870950959647889, 'f1': 0.49294829309647703}]
# Palaven. ROUGE evaluation finished for batch: 14.
# Palaven. Bertscore evaluation. Posted batch 14
# Palaven. ROUGE evaluation. Start processing batch: 15
# [{'rougeScoreType': 'rouge1', 'batchNumber': 15, 'precision': 0.4632305516503654, 'recall': 0.7133244381428797, 'f1': 0.5394546528173252}, {'rougeScoreType': 'rouge2', 'batchNumber': 15, 'precision': 0.3390477711011841, 'recall': 0.5319516207135123, 'f1': 0.3961144965645221}, {'rougeScoreType': 'rougeL', 'batchNumber': 15, 'precision': 0.3946247984228349, 'recall': 0.6169314179730709, 'f1': 0.4617388693358774}]
# Palaven. ROUGE evaluation finished for batch: 15.
# Palaven. Bertscore evaluation. Posted batch 15
# Palaven. ROUGE evaluation. Start processing batch: 16
# [{'rougeScoreType': 'rouge1', 'batchNumber': 16, 'precision': 0.5269293749520185, 'recall': 0.7553602994915615, 'f1': 0.5879627078451374}, {'rougeScoreType': 'rouge2', 'batchNumber': 16, 'precision': 0.3892799201929524, 'recall': 0.5645164240780995, 'f1': 0.4383374245490789}, {'rougeScoreType': 'rougeL', 'batchNumber': 16, 'precision': 0.46400270918436926, 'recall': 0.6734330149962243, 'f1': 0.5212229016070365}]
# Palaven. ROUGE evaluation finished for batch: 16.
# Palaven. Bertscore evaluation. Posted batch 16
# Palaven. ROUGE evaluation. Start processing batch: 17
# [{'rougeScoreType': 'rouge1', 'batchNumber': 17, 'precision': 0.4600588773456638, 'recall': 0.7668672993311979, 'f1': 0.5411928458406777}, {'rougeScoreType': 'rouge2', 'batchNumber': 17, 'precision': 0.3624819786521967, 'recall': 0.6082813162617294, 'f1': 0.4276340872954262}, {'rougeScoreType': 'rougeL', 'batchNumber': 17, 'precision': 0.4108568322870076, 'recall': 0.6873883669417609, 'f1': 0.48421830610595323}]
# Palaven. ROUGE evaluation finished for batch: 17.
# Palaven. Bertscore evaluation. Posted batch 17
# Palaven. ROUGE evaluation. Start processing batch: 18
# [{'rougeScoreType': 'rouge1', 'batchNumber': 18, 'precision': 0.4444186926435954, 'recall': 0.7655988865115338, 'f1': 0.5312529418407194}, {'rougeScoreType': 'rouge2', 'batchNumber': 18, 'precision': 0.36250849859945794, 'recall': 0.6123591704929983, 'f1': 0.43322655396967263}, {'rougeScoreType': 'rougeL', 'batchNumber': 18, 'precision': 0.40596460250199057, 'recall': 0.7040746461053924, 'f1': 0.48537053035009625}]
# Palaven. ROUGE evaluation finished for batch: 18.
# Palaven. Bertscore evaluation. Posted batch 18
# Palaven. ROUGE evaluation. Start processing batch: 19
# [{'rougeScoreType': 'rouge1', 'batchNumber': 19, 'precision': 0.5364800548882779, 'recall': 0.7623873310912778, 'f1': 0.6014419706319628}, {'rougeScoreType': 'rouge2', 'batchNumber': 19, 'precision': 0.4129870813814819, 'recall': 0.5983989343751022, 'f1': 0.4663381533014925}, {'rougeScoreType': 'rougeL', 'batchNumber': 19, 'precision': 0.49330505088951393, 'recall': 0.7036530480631719, 'f1': 0.5539425424279552}]
# Palaven. ROUGE evaluation finished for batch: 19.
# Palaven. Bertscore evaluation. Posted batch 19
# Palaven. ROUGE evaluation. Start processing batch: 20
# [{'rougeScoreType': 'rouge1', 'batchNumber': 20, 'precision': 0.4732780803653857, 'recall': 0.7590084480156931, 'f1': 0.5447065093844762}, {'rougeScoreType': 'rouge2', 'batchNumber': 20, 'precision': 0.3629931755302529, 'recall': 0.6065905655986987, 'f1': 0.4264344981120772}, {'rougeScoreType': 'rougeL', 'batchNumber': 20, 'precision': 0.4237185116199308, 'recall': 0.6865859307481679, 'f1': 0.49004188684963784}]
# Palaven. ROUGE evaluation finished for batch: 20.
# Palaven. Bertscore evaluation. Posted batch 20
# Palaven. ROUGE evaluation. Start processing batch: 21
# [{'rougeScoreType': 'rouge1', 'batchNumber': 21, 'precision': 0.4815475992267702, 'recall': 0.7796496672508682, 'f1': 0.5581100931339004}, {'rougeScoreType': 'rouge2', 'batchNumber': 21, 'precision': 0.39080564027014325, 'recall': 0.6551247411814586, 'f1': 0.45822479392099624}, {'rougeScoreType': 'rougeL', 'batchNumber': 21, 'precision': 0.44033262691820363, 'recall': 0.722613381036048, 'f1': 0.5138340812050634}]
# Palaven. ROUGE evaluation finished for batch: 21.
# Palaven. Bertscore evaluation. Posted batch 21
# Palaven. ROUGE evaluation. Start processing batch: 22
# [{'rougeScoreType': 'rouge1', 'batchNumber': 22, 'precision': 0.47889985500259485, 'recall': 0.7715350232160654, 'f1': 0.5341114793544236}, {'rougeScoreType': 'rouge2', 'batchNumber': 22, 'precision': 0.36056152345519216, 'recall': 0.5691390397412949, 'f1': 0.402320866027128}, {'rougeScoreType': 'rougeL', 'batchNumber': 22, 'precision': 0.41688720755414593, 'recall': 0.6779795047465129, 'f1': 0.4665208529406863}]
# Palaven. ROUGE evaluation finished for batch: 22.
# Palaven. Bertscore evaluation. Posted batch 22
# Palaven. ROUGE evaluation. Start processing batch: 23
# [{'rougeScoreType': 'rouge1', 'batchNumber': 23, 'precision': 0.49509905211940236, 'recall': 0.7626690638435221, 'f1': 0.5567327960646655}, {'rougeScoreType': 'rouge2', 'batchNumber': 23, 'precision': 0.39599114721466266, 'recall': 0.5619644443364357, 'f1': 0.44315853544060546}, {'rougeScoreType': 'rougeL', 'batchNumber': 23, 'precision': 0.44740600705259403, 'recall': 0.686188641128375, 'f1': 0.5011332098765995}]
# Palaven. ROUGE evaluation finished for batch: 23.
# Palaven. Bertscore evaluation. Posted batch 23
# Palaven. ROUGE evaluation. Start processing batch: 24
# [{'rougeScoreType': 'rouge1', 'batchNumber': 24, 'precision': 0.502739192476444, 'recall': 0.7534014076401497, 'f1': 0.5454858999042166}, {'rougeScoreType': 'rouge2', 'batchNumber': 24, 'precision': 0.40338382011825524, 'recall': 0.5747902474497074, 'f1': 0.4376611723455297}, {'rougeScoreType': 'rougeL', 'batchNumber': 24, 'precision': 0.4567697532573783, 'recall': 0.6935556733353045, 'f1': 0.49858902508435554}]
# Palaven. ROUGE evaluation finished for batch: 24.
# Palaven. Bertscore evaluation. Posted batch 24
# Palaven. ROUGE evaluation. Start processing batch: 25
# [{'rougeScoreType': 'rouge1', 'batchNumber': 25, 'precision': 0.467540166124722, 'recall': 0.8337464347110191, 'f1': 0.559096961575194}, {'rougeScoreType': 'rouge2', 'batchNumber': 25, 'precision': 0.3705414339513036, 'recall': 0.6610907197766202, 'f1': 0.44227236506504475}, {'rougeScoreType': 'rougeL', 'batchNumber': 25, 'precision': 0.42663755285560173, 'recall': 0.7603037445503489, 'f1': 0.5114348245121793}]
# Palaven. ROUGE evaluation finished for batch: 25.
# Palaven. Bertscore evaluation. Posted batch 25
# Palaven. ROUGE evaluation. Start processing batch: 26
# [{'rougeScoreType': 'rouge1', 'batchNumber': 26, 'precision': 0.36260106003104703, 'recall': 0.8333864151988098, 'f1': 0.4598768130696849}, {'rougeScoreType': 'rouge2', 'batchNumber': 26, 'precision': 0.29168060890106307, 'recall': 0.6156122357172766, 'f1': 0.36819084487767867}, {'rougeScoreType': 'rougeL', 'batchNumber': 26, 'precision': 0.33203366903824877, 'recall': 0.7699704424241187, 'f1': 0.42093448216638213}]
# Palaven. ROUGE evaluation finished for batch: 26.
# Palaven. Bertscore evaluation. Posted batch 26
# Palaven. ROUGE evaluation. Start processing batch: 27
# [{'rougeScoreType': 'rouge1', 'batchNumber': 27, 'precision': 0.47305593489259273, 'recall': 0.7881458819857917, 'f1': 0.5621516283620857}, {'rougeScoreType': 'rouge2', 'batchNumber': 27, 'precision': 0.3634198557724085, 'recall': 0.595697042093995, 'f1': 0.4311307152798778}, {'rougeScoreType': 'rougeL', 'batchNumber': 27, 'precision': 0.41038713154758044, 'recall': 0.6911579391873679, 'f1': 0.4893888070665558}]
# Palaven. ROUGE evaluation finished for batch: 27.
# Palaven. Bertscore evaluation. Posted batch 27
# Palaven. ROUGE evaluation. Start processing batch: 28
# [{'rougeScoreType': 'rouge1', 'batchNumber': 28, 'precision': 0.5578385851960731, 'recall': 0.7611101291893292, 'f1': 0.6211239405155761}, {'rougeScoreType': 'rouge2', 'batchNumber': 28, 'precision': 0.448756317723895, 'recall': 0.6111697816504129, 'f1': 0.49897681810137345}, {'rougeScoreType': 'rougeL', 'batchNumber': 28, 'precision': 0.4757487663369008, 'recall': 0.6538312656509985, 'f1': 0.5307239900926496}]
# Palaven. ROUGE evaluation finished for batch: 28.
# Palaven. Bertscore evaluation. Posted batch 28

# %% [markdown]
# ### 4.3. BLEU

# %%
from nltk.translate.bleu_score import sentence_bleu

for batch_number in range(1, 29):

    model_responses_df = build_responses_df()

    print(f'Palaven. BLEU evaluation. Start processing batch: {batch_number}')

    model_responses = palaven_api.fetch_model_responses(evaluation_session_id, 'llmfinetunedrag', batch_number)

    for item in model_responses:
        add_response_to_df(model_responses_df, item)

    references = model_responses_df['response'].tolist()
    candidates = model_responses_df['response_to_evaluate'].tolist()

    bleu_scores = []

    for candidate, reference in zip(candidates, references):
        reference_tokens = [reference.split()]
        candidate_tokens = candidate.split()
        bleu_score = sentence_bleu(reference_tokens, candidate_tokens)
        bleu_scores.append(bleu_score)

    average_bleu = sum(bleu_scores) / len(bleu_scores)

    print(f'Palaven. BLEU evaluation. Batch: {batch_number}. Average BLEU score: {average_bleu}')

    palaven_api.save_bleu_score_metrics(evaluation_session_id, 'llmfinetunedrag', batch_number, average_bleu)

    print(f'Palaven. BLEU evaluation. Posted batch {batch_number}')
# Out:
# Palaven. BLEU evaluation. Start processing batch: 1
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 1. Average BLEU score: 0.24608320713895984
# Palaven. BLEU evaluation. Posted batch 1
# Palaven. BLEU evaluation. Start processing batch: 2
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 2. Average BLEU score: 0.35915124674546317
# Palaven. BLEU evaluation. Posted batch 2
# Palaven. BLEU evaluation. Start processing batch: 3
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 3. Average BLEU score: 0.35595469879725994
# Palaven. BLEU evaluation. Posted batch 3
# Palaven. BLEU evaluation. Start processing batch: 4
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 4. Average BLEU score: 0.2890967898158282
# Palaven. BLEU evaluation. Posted batch 4
# Palaven. BLEU evaluation. Start processing batch: 5
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 5. Average BLEU score: 0.2983181480783415
# Palaven. BLEU evaluation. Posted batch 5
# Palaven. BLEU evaluation. Start processing batch: 6
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 6. Average BLEU score: 0.28782399819698645
# Palaven. BLEU evaluation. Posted batch 6
# Palaven. BLEU evaluation. Start processing batch: 7
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 7. Average BLEU score: 0.3254914404219893
# Palaven. BLEU evaluation. Posted batch 7
# Palaven. BLEU evaluation. Start processing batch: 8
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 8. Average BLEU score: 0.24861175686201645
# Palaven. BLEU evaluation. Posted batch 8
# Palaven. BLEU evaluation. Start processing batch: 9
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 9. Average BLEU score: 0.2966919908312973
# Palaven. BLEU evaluation. Posted batch 9
# Palaven. BLEU evaluation. Start processing batch: 10
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 10. Average BLEU score: 0.3868642659674051
# Palaven. BLEU evaluation. Posted batch 10
# Palaven. BLEU evaluation. Start processing batch: 11
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 11. Average BLEU score: 0.26776561216619593
# Palaven. BLEU evaluation. Posted batch 11
# Palaven. BLEU evaluation. Start processing batch: 12
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 12. Average BLEU score: 0.232960755949153
# Palaven. BLEU evaluation. Posted batch 12
# Palaven. BLEU evaluation. Start processing batch: 13
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 13. Average BLEU score: 0.31997950995159036
# Palaven. BLEU evaluation. Posted batch 13
# Palaven. BLEU evaluation. Start processing batch: 14
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 14. Average BLEU score: 0.2820684743427818
# Palaven. BLEU evaluation. Posted batch 14
# Palaven. BLEU evaluation. Start processing batch: 15
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 15. Average BLEU score: 0.25706087238936953
# Palaven. BLEU evaluation. Posted batch 15
# Palaven. BLEU evaluation. Start processing batch: 16
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 16. Average BLEU score: 0.2916328806315024
# Palaven. BLEU evaluation. Posted batch 16
# Palaven. BLEU evaluation. Start processing batch: 17
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 17. Average BLEU score: 0.28853338081871294
# Palaven. BLEU evaluation. Posted batch 17
# Palaven. BLEU evaluation. Start processing batch: 18
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 18. Average BLEU score: 0.3029523273549435
# Palaven. BLEU evaluation. Posted batch 18
# Palaven. BLEU evaluation. Start processing batch: 19
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 19. Average BLEU score: 0.32764684945210837
# Palaven. BLEU evaluation. Posted batch 19
# Palaven. BLEU evaluation. Start processing batch: 20
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 20. Average BLEU score: 0.27368385614567553
# Palaven. BLEU evaluation. Posted batch 20
# Palaven. BLEU evaluation. Start processing batch: 21
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 21. Average BLEU score: 0.302574776285466
# Palaven. BLEU evaluation. Posted batch 21
# Palaven. BLEU evaluation. Start processing batch: 22
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 22. Average BLEU score: 0.2530035332233514
# Palaven. BLEU evaluation. Posted batch 22
# Palaven. BLEU evaluation. Start processing batch: 23
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 23. Average BLEU score: 0.29900793134501175
# Palaven. BLEU evaluation. Posted batch 23
# Palaven. BLEU evaluation. Start processing batch: 24
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 24. Average BLEU score: 0.3042488891956325
# Palaven. BLEU evaluation. Posted batch 24
# Palaven. BLEU evaluation. Start processing batch: 25
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 25. Average BLEU score: 0.2919342492942466
# Palaven. BLEU evaluation. Posted batch 25
# Palaven. BLEU evaluation. Start processing batch: 26
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 26. Average BLEU score: 0.2400982006000456
# Palaven. BLEU evaluation. Posted batch 26
# Palaven. BLEU evaluation. Start processing batch: 27
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Palaven. BLEU evaluation. Batch: 27. Average BLEU score: 0.27571894761257554
# Palaven. BLEU evaluation. Posted batch 27
# Palaven. BLEU evaluation. Start processing batch: 28
# Palaven. BLEU evaluation. Batch: 28. Average BLEU score: 0.38504342359649585
# Palaven. BLEU evaluation. Posted batch 28
